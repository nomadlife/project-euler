# %% [markdown]
# # P051 Prime digit replacement
#
# By replacing the 1st digit of the 2-digit number *3, it turns out that six of the nine possible values: 13, 23, 43, 53, 73, and 83, are all prime.
# By replacing the 3rd and 4th digits of 56**3 with the same digit, this 5-digit number is the first example having seven primes among the ten generated numbers, yielding the family: 56003, 56113, 56333, 56443, 56663, 56773, and 56993. Consequently 56003, being the first member of this family, is the smallest prime with this property.
# Find the smallest prime which, by replacing part of the number (not necessarily adjacent digits) with the same digit, is part of an eight prime value family.

# %%
# 끝자리가 '1379'일때만 실행 -1
for i in range(100,120):
    string = str(i)
    if string[-1] in '1379':
        print(i)
# Out:
# 101
# 103
# 107
# 109
# 111
# 113
# 117
# 119

# %%
# 끝자리가 '1379'일때만 실행 -2
for i in range(100,120):
    if i%10 in (1,3,5,7):
        print(i)
# Out:
# 101
# 103
# 105
# 107
# 111
# 113
# 115
# 117

# %%
a=(1,3,5,7)
b=range(1,8,2)
type(b)
# Out:
# range

# %%
def getDigit(num):
    if num < 10:
        print(num)
    else:
        get_digit(num // 10)
        print(num % 10)
get_digit(543267)
# Out:
# 5
# 4
# 3
# 2
# 6
# 7

# %%
def isPrime(num):
    if num==1:
        return False
    loop=num**0.5
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

    
for i in range(100,120):
    string = str(i)
    if string[-1] in '1379':
        print(i,isPrime(i))
# Out:
# 101 True
# 103 True
# 107 True
# 109 True
# 111 False
# 113 True
# 117 False
# 119 False

# %%
def isPrime(num):
    if num==1: return False
    i=2
    loop = num**0.5
    while i <= loop:
        if num%i==0: return False
        i+=1
    return True
    
for i in range(100,120):
    string = str(i)
    if string[-1] in '1379':
        print(i,isPrime(i))
# Out:
# 101 True
# 103 True
# 107 True
# 109 True
# 111 False
# 113 True
# 117 False
# 119 False

# %%
# 소수 체크, 끝자리 1379 일때만. 
for i in range(100,10000):
    if i%10 in (1,3,7,9) and isPrime(i): 
        print(i, end='')
# Out:
# ...

# %%
# checkPrimeFamily 함수 

def checkPrimeFamily(num):
    string = str(num)
    for i in range(len(string)):
        newStr = string[:i]+'.'+','+string[i:]
        if True : 
            print(newStr)
    return True
    
for i in range(100,120):
    if i%10 in (1,3,7,9):
        print("i:",i)
        checkPrimeFamily(i)
# Out:
# i: 101
# .,101
# 1.,01
# 10.,1
# i: 103
# .,103
# 1.,03
# 10.,3
# i: 107
# .,107
# 1.,07
# 10.,7
# i: 109
# .,109
# 1.,09
# 10.,9
# i: 111
# .,111
# 1.,11
# 11.,1
# i: 113
# .,113
# 1.,13
# 11.,3
# i: 117
# .,117
# 1.,17
# 11.,7
# i: 119
# .,119
# 1.,19
# 11.,9

# %%
# step 2 - checkPrimeFamily 함수

def checkPrimeFamily(num):
    string = str(num)
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+'.'+string[i:j]+','+string[j:]
                if True : result.append(newStr)
            print(result,len(result))
    return True
    
for i in range(1000,1020):
    if i%10 in (1,3,7,9):
        print("i:",i)
        checkPrimeFamily(i)
# Out:
# i: 1001
# ['.,1001', '.,1001', '.,1001', '.,1001', '.,1001', '.,1001', '.,1001', '.,1001', '.,1001', '.,1001'] 10
# ['.1,001', '.1,001', '.1,001', '.1,001', '.1,001', '.1,001', '.1,001', '.1,001', '.1,001', '.1,001'] 10
# ['.10,01', '.10,01', '.10,01', '.10,01', '.10,01', '.10,01', '.10,01', '.10,01', '.10,01', '.10,01'] 10
# ['.100,1', '.100,1', '.100,1', '.100,1', '.100,1', '.100,1', '.100,1', '.100,1', '.100,1', '.100,1'] 10
# ['1.,001', '1.,001', '1.,001', '1.,001', '1.,001', '1.,001', '1.,001', '1.,001', '1.,001', '1.,001'] 10
# ['1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01', '1.0,01'] 10
# ['1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1', '1.00,1'] 10
# ['10.,01', '10.,01', '10.,01', '10.,01', '10.,01', '10.,01', '10.,01', '10.,01', '10.,01', '10.,01'] 10
# ['10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1', '10.0,1'] 10
# ...

# %%
# step 3 - checkPrimeFamily 함수
def checkPrimeFamily(num):
    string = str(num)
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+str(k)+string[i:j]+str(k)+string[j:]
                if isPrime(int(newStr)) : result.append(newStr)
            print(result,len(result))
    return True
    
for i in range(100,120):
    if i%10 in (1,3,7,9):
        print("i:",i)
        checkPrimeFamily(i)
# Out:
# i: 101
# ['00101', '44101', '77101'] 3
# [] 0
# [] 0
# ['14401'] 1
# ['16061'] 1
# ['10111', '10331', '10771'] 3
# i: 103
# ['00103', '55103', '66103', '99103'] 4
# ['51503', '61603'] 2
# ['21023', '31033', '81083'] 3
# ['12203', '16603', '18803'] 3
# ['13033', '15053', '16063'] 3
# ['10223', '10333', '10663', '10883', '10993'] 5
# i: 107
# ['00107', '33107', '66107'] 3
# ['31307', '71707'] 2
# ['41047', '91097'] 2
# ['10007', '14407', '16607', '17707'] 4
# ['10007', '13037', '16067', '17077'] 4
# ['10007', '10337', '10667'] 3
# i: 109
# ['00109', '22109', '55109', '66109', '99109'] 5
# ['01009', '61609', '91909'] 3
# ['01009', '31039', '51059', '91099'] 4
# ['10009', '13309'] 2
# ['10009', '16069', '18089'] 3
# ['10009', '10559', '10889'] 3
# i: 111
# ['22111', '44111'] 2
# ['21211', '41411', '51511', '71711'] 4
# ['21121', '41141', '51151', '71171', '81181'] 5
# ['12211', '14411', '15511'] 3
# ['18181'] 1
# ['11551'] 1
# i: 113
# ['00113', '11113', '33113'] 3
# ...

# %%
# step 4 - scale up 
# (~1000, target 6, not consecutive)

def checkPrimeFamily(num):
    string = str(num)
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+str(k)+string[i:j]+str(k)+string[j:]
                if isPrime(int(newStr)) : result.append(newStr)
            if len(result) >= 6:
                print('loop',num,result)

for i in range(100,1000):
    if i%10 in (1,3,7,9):
        checkPrimeFamily(i)
# Out:
# loop 119 ['01109', '11119', '31139', '41149', '61169', '91199']
# loop 121 ['01201', '21221', '31231', '61261', '81281', '91291']
# loop 131 ['10301', '11311', '13331', '14341', '16361', '19391']
# loop 161 ['10061', '11161', '14461', '16661', '17761', '19961']
# loop 563 ['56003', '56113', '56333', '56443', '56663', '56773', '56993']
# loop 587 ['00587', '11587', '33587', '44587', '66587', '77587']
# loop 617 ['00617', '11617', '33617', '44617', '66617', '77617']
# loop 703 ['70003', '73303', '75503', '76603', '78803', '79903']
# loop 721 ['22721', '33721', '55721', '66721', '88721', '99721']
# loop 757 ['07507', '27527', '37537', '57557', '67567', '87587']
# loop 811 ['08011', '28211', '58511', '68611', '88811', '98911']
# loop 973 ['29723', '39733', '59753', '69763', '89783', '99793']

# %%
# step 5 - result rearrange & scle up & time measure
# (~5000, target 7, not consecutive)

def checkPrimeFamily(num):
    string = str(num)
    resultSum=[]
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+str(k)+string[i:j]+str(k)+string[j:]
                if isPrime(int(newStr)) : result.append(newStr)
            if len(result) >= 7:
                resultSum.append(result)
    return resultSum

start_time = time.time() 
for i in range(100,5000):
    if i%10 in (1,3,7,9):
        calc = checkPrimeFamily(i)
        if len(calc):
            print('loop:',i,calc)
print("time:",(time.time() - start_time))
# Out:
# loop: 563 [['56003', '56113', '56333', '56443', '56663', '56773', '56993']]
# loop: 1211 [['012011', '112111', '312311', '412411', '612611', '712711', '912911']]
# loop: 2119 [['021019', '221219', '321319', '521519', '621619', '821819', '921919']]
# loop: 2521 [['205201', '225221', '235231', '255251', '265261', '285281', '295291']]
# loop: 3299 [['032099', '132199', '332399', '432499', '632699', '732799', '932999']]
# time: 22.454749584197998

# %%
# step 6 - speed up (~5000, target 7, consecutive only)
def checkPrimeFamily(num,target):
    string = str(num)
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+str(k)+string[i:j]+str(k)+string[j:]
                if isPrime(int(newStr)) : result.append(newStr)
                elif str(k) in '3456' : break
            if len(result) >= target:
                print(num,result)

startTime = time.time()                 
for i in range(100,5000):
    if i%10 in (1,3,7,9):
        checkPrimeFamily(i,7)
        
print("time:",(time.time() - startTime))
# Out:
# time: 8.219454288482666

# %%
# step 7 - scale up (~10000, target 8)
def checkPrimeFamily(num,target):
    string = str(num)
    for i in range(len(string)):
        for j in range(i,len(string)):
            result=[]
            for k in range(10):
                newStr = string[:i]+str(k)+string[i:j]+str(k)+string[j:]
                if isPrime(int(newStr)) : result.append(newStr)
                elif str(k) in '234567' : break
            if len(result) >= target:
                print(num,result)
startTime = time.time() 
for i in range(100,10000):
    if i%10 in (1,3,7,9):
        checkPrimeFamily(i,8)
print("time:",time.time() - startTime)
# Out:
# time: 15.219846963882446

# %%
# split more than two

def checkPrimeFamily(num):
    string = str(num)[:-1]
    target=8
    for k in '0123456789':
        for i in range(100):
        newStr=
        if isPrime(int(newStr)):
            result.append(newStr)
        elif k in '234567' :break
    if len(result) >= target:
        print(num,result)

for i in range(10000,1000000):
    if i%10 in (1,3,7,9):
        checkPrimeFamily(i)
print('calc end')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-144-57fe7c554ee8> in <module>()
#      18 for i in range(10000,1000000):
#      19     if i%10 in (1,3,7,9):
# ---> 20         checkPrimeFamily(i)
#      21 print('calc end')
#
# <ipython-input-144-57fe7c554ee8> in checkPrimeFamily(num)
#      10             for k in '0123456789':
#      11                 newStr=string.replace(i,k)+str(num)[-1]
# ---> 12                 if isPrime(int(newStr)):
#      13                     result.append(newStr)
#      14                 elif k in '234567' :break
#
# <ipython-input-117-e1104837e556> in isPrime(num)
#      12         if num%i==0:
#      13             return False
# ---> 14         i+=1
#      15     return True
#      16
#
# KeyboardInterrupt:
