# %% [markdown]
# # p071 Ordered fractions

# %%
1000000*3/7
# Out:
# 428571.4285714286

# %%
999999*3/7
# Out:
# 428571.0

# %%
999998*3/7
# Out:
# 428570.5714285714

# %%
999997*3/7
# Out:
# 428570.14285714284

# %%
value = 1000000*3/7
int(value)
# Out:
# 428571

# %%
from sympy import isprime
isprime(value)
# Out:
# False

# %%
from math import gcd
gcd(428571,1000000)
# Out:
# 1

# %%
# sol-1 
# too slow
basis=(2,5)
for i in range(1,1000000):
    value=i*3/7
    if int(value)/i < 3/7 and int(value)/i > basis[0]/basis[1]:
        basis=(int(value),i)
        print(basis)
# Out:
# (5, 12)
# (8, 19)
# (11, 26)
# (14, 33)
# (17, 40)
# (20, 47)
# (23, 54)
# (26, 61)
# (29, 68)
# (32, 75)
# (35, 82)
# (38, 89)
# (41, 96)
# (44, 103)
# (47, 110)
# (50, 117)
# (53, 124)
# (56, 131)
# (59, 138)
# (62, 145)
# (65, 152)
# (68, 159)
# (71, 166)
# (74, 173)
# (77, 180)
# (80, 187)
# (83, 194)
# (86, 201)
# (89, 208)
# (92, 215)
# (95, 222)
# (98, 229)
# (101, 236)
# (104, 243)
# (107, 250)
# (110, 257)
# (113, 264)
# (116, 271)
# (119, 278)
# (122, 285)
# (125, 292)
# (128, 299)
# (131, 306)
# (134, 313)
# (137, 320)
# (140, 327)
# (143, 334)
# (146, 341)
# (149, 348)
# (152, 355)
# (155, 362)
# (158, 369)
# (161, 376)
# (164, 383)
# (167, 390)
# (170, 397)
# (173, 404)
# (176, 411)
# (179, 418)
# (182, 425)
# (185, 432)
# (188, 439)
# (191, 446)
# (194, 453)
# (197, 460)
# (200, 467)
# (203, 474)
# (206, 481)
# (209, 488)
# (212, 495)
# (215, 502)
# (218, 509)
# (221, 516)
# (224, 523)
# (227, 530)
# (230, 537)
# (233, 544)
# (236, 551)
# (239, 558)
# (242, 565)
# ...

# %%
basis=(2,5)
for i in range(1000000,1,-1):
    value=i*3/7
    if int(value)/i < 3/7 and int(value)/i > basis[0]/basis[1]:
        basis=(int(value),i)
        print(basis)
# Out:
# (428571, 1000000)
# (428570, 999997)

# %%
basis=2/5
for i in range(1000000,1,-1):
    value=i*3/7
    if int(value)/i < 3/7 and int(value)/i > basis:
        basis=int(value)/i
        print(int(value),i)
# Out:
# 428571 1000000
# 428570 999997

# %%
from math import gcd
basis=2/5
for i in range(1000000,1,-1):
    value=int(i*3/7)
    if value/i < 3/7 and value/i > basis:
        basis=value/i
        print(value,i,gcd(value,i))
# Out:
# 428571 1000000 1
# 428570 999997 1
