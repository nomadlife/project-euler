# %% [markdown]
# # Q037 Truncatable primes
#
#
# The number 3797 has an interesting property. Being prime itself, it is possible to continuously remove digits from left to right, and remain prime at each stage: 3797, 797, 97, and 7. Similarly we can work from right to left: 3797, 379, 37, and 3.
#
# Find the sum of the only eleven primes that are both truncatable from left to right and right to left.
#
# NOTE: 2, 3, 5, and 7 are not considered to be truncatable primes.

# %%
# 소수확인 함수
def is_prime(num):
    if num==1 or num==0:
        return False
    loop=pow(num,0.5)
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

number=100
while number<200:
    # 소수확인 
    if is_prime(number):
        print(number, "prime")
    number+=1
# Out:
# 101 prime
# 103 prime
# 107 prime
# 109 prime
# 113 prime
# 127 prime
# 131 prime
# 137 prime
# 139 prime
# 149 prime
# 151 prime
# 157 prime
# 163 prime
# 167 prime
# 173 prime
# 179 prime
# 181 prime
# 191 prime
# 193 prime
# 197 prime
# 199 prime

# %%
# 숫자 slice 하기.
number=100
while number<200:
    string=str(number)
    test=''
    for i in string:
        test+=i
        print(number,test)
    number+=1
# Out:
# 100 1
# 100 10
# 100 100
# 101 1
# 101 10
# 101 101
# 102 1
# 102 10
# 102 102
# 103 1
# 103 10
# 103 103
# 104 1
# 104 10
# 104 104
# 105 1
# 105 10
# 105 105
# 106 1
# 106 10
# 106 106
# 107 1
# 107 10
# 107 107
# 108 1
# 108 10
# 108 108
# 109 1
# 109 10
# 109 109
# 110 1
# 110 11
# 110 110
# 111 1
# 111 11
# 111 111
# 112 1
# 112 11
# 112 112
# 113 1
# 113 11
# 113 113
# 114 1
# 114 11
# 114 114
# 115 1
# 115 11
# 115 115
# 116 1
# 116 11
# 116 116
# 117 1
# 117 11
# 117 117
# 118 1
# 118 11
# 118 118
# 119 1
# 119 11
# 119 119
# 120 1
# 120 12
# 120 120
# 121 1
# 121 12
# 121 121
# 122 1
# 122 12
# 122 122
# 123 1
# 123 12
# 123 123
# 124 1
# 124 12
# 124 124
# 125 1
# 125 12
# 125 125
# 126 1
# 126 12
# 126 126
# 127 1
# 127 12
# 127 127
# 128 1
# 128 12
# 128 128
# 129 1
# 129 12
# 129 129
# 130 1
# 130 13
# 130 130
# 131 1
# 131 13
# 131 131
# 132 1
# 132 13
# 132 132
# 133 1
# 133 13
# 133 133
# 134 1
# 134 13
# 134 134
# 135 1
# 135 13
# 135 135
# 136 1
# 136 13
# 136 136
# ...

# %%
# truncatable 확인 함수
def is_prime(num):
    if num==1 or num==0:
        return False
    loop=pow(num,0.5)
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

def is_truncatable_prime(num):
    string = str(num)
    string2 = ''
    for i in string:
        string2 += i
        if not is_prime(int(string2)):
            return False
    return True

number=100;count=0;total=0
while number<200:
    if is_truncatable_prime(number):
        count+=1;total+=number
        print(number,count)
    if count==11:
        break
    number+=1
print(total)
# Out:
# 0

# %%
# 1000까지
def is_prime(num):
    if num==1 or num==0:
        return False
    loop=pow(num,0.5)
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

def is_truncatable_prime(num):
    string = str(num)
    string2 = ''
    for i in string:
        string2 += i
        if not is_prime(int(string2)):
            return False
    return True

number=100;count=0;total=0
while number<1000:
    if is_truncatable_prime(number):
        count+=1;total+=number
        print(number,count)
    if count==11:
        break
    number+=1
print(total)
# Out:
# 233 1
# 239 2
# 293 3
# 311 4
# 313 5
# 317 6
# 373 7
# 379 8
# 593 9
# 599 10
# 719 11
# 4369

# %%
def is_prime(num):
    if num==1 or num==0:
        return False
    loop=pow(num,0.5)
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

number=10
while number<1000:
    if not is_prime(number):
        number+=1
        continue
    truncatable = True
    string=str(number)
    print("number:",number)
    for i in range(1,len(string)):
        print(string[:i],string[i:],is_prime(int(string[:i])),is_prime(int(string[i:])))
        # 소수아닌수가 있으면, truncatable 이 아님.
        if not is_prime(int(string[:i])) or not is_prime(int(string[i:])):
            truncatable = False
            break
    # truncatable 하면 표시.
    if truncatable == True:
        print(number,"is truncatable")
    number+=1
# Out:
# number: 11
# 1 1 False False
# number: 13
# 1 3 False True
# number: 17
# 1 7 False True
# number: 19
# 1 9 False False
# number: 23
# 2 3 True True
# 23 is truncatable
# number: 29
# 2 9 True False
# number: 31
# 3 1 True False
# number: 37
# 3 7 True True
# 37 is truncatable
# number: 41
# 4 1 False False
# number: 43
# 4 3 False True
# number: 47
# 4 7 False True
# number: 53
# 5 3 True True
# 53 is truncatable
# number: 59
# 5 9 True False
# number: 61
# 6 1 False False
# number: 67
# 6 7 False True
# number: 71
# 7 1 True False
# number: 73
# 7 3 True True
# 73 is truncatable
# number: 79
# 7 9 True False
# number: 83
# 8 3 False True
# number: 89
# 8 9 False False
# number: 97
# 9 7 False True
# number: 101
# 1 01 False False
# number: 103
# 1 03 False True
# number: 107
# 1 07 False True
# number: 109
# 1 09 False False
# number: 113
# 1 13 False True
# number: 127
# 1 27 False False
# number: 131
# 1 31 False True
# number: 137
# 1 37 False True
# number: 139
# ...

# %%
def is_prime(num):
    if num==1 or num==0:
        return False
    loop=pow(num,0.5)
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

number=10;count=0;total=0
#count가 11이 될때까지 계산.
while count<11:
    if not is_prime(number):
        number+=1
        continue
    truncatable = True
    string=str(number)
    for i in range(1,len(string)):
        if not is_prime(int(string[:i])) or not is_prime(int(string[i:])):
            truncatable = False
            break
    if truncatable == True:
        # 카운트,합산
        count+=1;total+=number
        print(number,"is truncatable",count,total)
    number+=1
# Out:
# 23 is truncatable 1 23
# 37 is truncatable 2 60
# 53 is truncatable 3 113
# 73 is truncatable 4 186
# 313 is truncatable 5 499
# 317 is truncatable 6 816
# 373 is truncatable 7 1189
# 797 is truncatable 8 1986
# 3137 is truncatable 9 5123
# 3797 is truncatable 10 8920
# 739397 is truncatable 11 748317
