# %% [markdown]
# # Q041 Pandigital prime
#
# We shall say that an n-digit number is pandigital if it makes use of all the digits 1 to n exactly once. For example, 2143 is a 4-digit pandigital and is also prime.
#
# What is the largest n-digit pandigital prime that exists?

# %%
# is_pandigit 함수
def is_pandigit(num):
    string=str(num)
    for i in range(1,len(string)+1):
        if not str(i) in string:
            return False
    return True
        
print(is_pandigit("123465"))
# Out:
# True

# %%
def is_prime(num):
    if num==1:
        return False
    loop=num**0.5
    i=2
    while i<=loop:
        if num%i==0:
            return False
        i+=1
    return True

for n in range(231,232):
    print(n,is_prime(n))
# Out:
# 231 False

# %%
number = 1
while True:
    if is_pandigit(number):
        #print("pandigital number",number)
        if is_prime(number):
            print(number,"is pandigit & prime number")
    number+=1
# Out:
# 1423 is pandigit & prime number
# 2143 is pandigit & prime number
# 2341 is pandigit & prime number
# 4231 is pandigit & prime number
# 1234657 is pandigit & prime number
# 1245763 is pandigit & prime number
# 1246537 is pandigit & prime number
# 1246573 is pandigit & prime number
# 1247563 is pandigit & prime number
# 1254367 is pandigit & prime number
# 1254637 is pandigit & prime number
# 1256347 is pandigit & prime number
# 1257463 is pandigit & prime number
# 1263547 is pandigit & prime number
# 1264537 is pandigit & prime number
# 1264573 is pandigit & prime number
# 1265347 is pandigit & prime number
# 1275643 is pandigit & prime number
# 1276543 is pandigit & prime number
# 1324567 is pandigit & prime number
# 1342567 is pandigit & prime number
# 1342657 is pandigit & prime number
# 1345627 is pandigit & prime number
# 1354267 is pandigit & prime number
# 1356247 is pandigit & prime number
# 1356427 is pandigit & prime number
# 1362457 is pandigit & prime number
# 1425367 is pandigit & prime number
# 1426753 is pandigit & prime number
# 1427563 is pandigit & prime number
# 1427653 is pandigit & prime number
# 1435627 is pandigit & prime number
# 1436257 is pandigit & prime number
# 1436527 is pandigit & prime number
# 1452637 is pandigit & prime number
# 1453267 is pandigit & prime number
# 1463257 is pandigit & prime number
# 1465273 is pandigit & prime number
# 1476253 is pandigit & prime number
# 1476523 is pandigit & prime number
# 1524637 is pandigit & prime number
# 1524763 is pandigit & prime number
# 1532647 is pandigit & prime number
# 1546273 is pandigit & prime number
# 1546327 is pandigit & prime number
# 1562347 is pandigit & prime number
# 1563427 is pandigit & prime number
# 1564237 is pandigit & prime number
# 1572643 is pandigit & prime number
# 1574623 is pandigit & prime number
# 1576243 is pandigit & prime number
# 1624573 is pandigit & prime number
# 1625347 is pandigit & prime number
# 1632457 is pandigit & prime number
# 1634257 is pandigit & prime number
# 1645327 is pandigit & prime number
# 1647253 is pandigit & prime number
# 1647523 is pandigit & prime number
# 1652347 is pandigit & prime number
# 1653427 is pandigit & prime number
# 1672453 is pandigit & prime number
# 1674523 is pandigit & prime number
# 1725463 is pandigit & prime number
# 1726453 is pandigit & prime number
# 1742563 is pandigit & prime number
# 1752643 is pandigit & prime number
# 1764253 is pandigit & prime number
# 2136457 is pandigit & prime number
# 2143567 is pandigit & prime number
# 2145763 is pandigit & prime number
# 2146357 is pandigit & prime number
# 2153647 is pandigit & prime number
# 2156437 is pandigit & prime number
# 2163547 is pandigit & prime number
# 2176543 is pandigit & prime number
# 2315647 is pandigit & prime number
# 2341567 is pandigit & prime number
# 2345617 is pandigit & prime number
# 2347561 is pandigit & prime number
# 2354167 is pandigit & prime number
# 2364517 is pandigit & prime number
# 2365471 is pandigit & prime number
# 2375641 is pandigit & prime number
# 2376541 is pandigit & prime number
# 2413657 is pandigit & prime number
# 2431657 is pandigit & prime number
# 2436517 is pandigit & prime number
# 2436571 is pandigit & prime number
# 2451367 is pandigit & prime number
# 2451637 is pandigit & prime number
# 2456371 is pandigit & prime number
# 2456731 is pandigit & prime number
# 2457361 is pandigit & prime number
# 2457613 is pandigit & prime number
# 2467351 is pandigit & prime number
# 2475163 is pandigit & prime number
# 2476351 is pandigit & prime number
# 2516473 is pandigit & prime number
# 2534671 is pandigit & prime number
# 2536147 is pandigit & prime number
# 2537461 is pandigit & prime number
# 2543617 is pandigit & prime number
# 2546317 is pandigit & prime number
# 2547361 is pandigit & prime number
# 2547613 is pandigit & prime number
# 2547631 is pandigit & prime number
# 2561743 is pandigit & prime number
# 2563147 is pandigit & prime number
# 2563417 is pandigit & prime number
# 2576341 is pandigit & prime number
# 2613547 is pandigit & prime number
# 2631457 is pandigit & prime number
# 2634517 is pandigit & prime number
# 2637451 is pandigit & prime number
# 2637541 is pandigit & prime number
# 2641357 is pandigit & prime number
# 2645371 is pandigit & prime number
# 2647531 is pandigit & prime number
# 2651437 is pandigit & prime number
# 2651743 is pandigit & prime number
# 2653741 is pandigit & prime number
# 2654317 is pandigit & prime number
# 2654371 is pandigit & prime number
# 2657143 is pandigit & prime number
# 2657341 is pandigit & prime number
# 2674513 is pandigit & prime number
# 2674531 is pandigit & prime number
# 2714563 is pandigit & prime number
# 2716453 is pandigit & prime number
# 2716543 is pandigit & prime number
# 2734561 is pandigit & prime number
# 2735641 is pandigit & prime number
# 2736451 is pandigit & prime number
# 2741653 is pandigit & prime number
# 2743561 is pandigit & prime number
# 2745361 is pandigit & prime number
# 2754361 is pandigit & prime number
# 2761453 is pandigit & prime number
# 2761543 is pandigit & prime number
# 2765143 is pandigit & prime number
# 3124567 is pandigit & prime number
# 3124657 is pandigit & prime number
# 3126457 is pandigit & prime number
# 3126547 is pandigit & prime number
# 3145627 is pandigit & prime number
# 3152467 is pandigit & prime number
# 3154267 is pandigit & prime number
# 3156427 is pandigit & prime number
# 3165427 is pandigit & prime number
# 3214567 is pandigit & prime number
# 3214657 is pandigit & prime number
# 3215467 is pandigit & prime number
# 3216457 is pandigit & prime number
# 3241657 is pandigit & prime number
# 3245761 is pandigit & prime number
# 3246157 is pandigit & prime number
# 3246751 is pandigit & prime number
# 3251467 is pandigit & prime number
# 3254761 is pandigit & prime number
# 3256417 is pandigit & prime number
# 3256471 is pandigit & prime number
# 3257641 is pandigit & prime number
# 3261547 is pandigit & prime number
# 3264571 is pandigit & prime number
# 3265741 is pandigit & prime number
# 3412567 is pandigit & prime number
# 3412657 is pandigit & prime number
# 3415627 is pandigit & prime number
# 3421567 is pandigit & prime number
# 3421657 is pandigit & prime number
# 3427561 is pandigit & prime number
# 3451627 is pandigit & prime number
# 3452671 is pandigit & prime number
# 3456127 is pandigit & prime number
# 3456217 is pandigit & prime number
# 3456721 is pandigit & prime number
# 3457261 is pandigit & prime number
# 3461257 is pandigit & prime number
# 3462517 is pandigit & prime number
# 3462751 is pandigit & prime number
# 3465271 is pandigit & prime number
# 3467251 is pandigit & prime number
# 3467521 is pandigit & prime number
# 3475261 is pandigit & prime number
# 3512647 is pandigit & prime number
# 3514267 is pandigit & prime number
# 3516427 is pandigit & prime number
# 3524617 is pandigit & prime number
# 3526147 is pandigit & prime number
# 3526741 is pandigit & prime number
# 3542167 is pandigit & prime number
# 3542761 is pandigit & prime number
# 3546271 is pandigit & prime number
# 3546721 is pandigit & prime number
# 3561247 is pandigit & prime number
# 3562417 is pandigit & prime number
# 3574621 is pandigit & prime number
# 3576421 is pandigit & prime number
# 3612457 is pandigit & prime number
# 3612547 is pandigit & prime number
# 3624157 is pandigit & prime number
# 3627451 is pandigit & prime number
# 3642157 is pandigit & prime number
# 3642571 is pandigit & prime number
# 3672451 is pandigit & prime number
# 3672541 is pandigit & prime number
# 3674521 is pandigit & prime number
# 3675241 is pandigit & prime number
# 3725461 is pandigit & prime number
# 3742561 is pandigit & prime number
# 3746521 is pandigit & prime number
# 3752641 is pandigit & prime number
# 3756241 is pandigit & prime number
# 3756421 is pandigit & prime number
# 3765241 is pandigit & prime number
# 4125637 is pandigit & prime number
# 4125673 is pandigit & prime number
# 4126537 is pandigit & prime number
# 4127653 is pandigit & prime number
# 4135627 is pandigit & prime number
# 4152763 is pandigit & prime number
# 4157623 is pandigit & prime number
# 4165327 is pandigit & prime number
# 4167523 is pandigit & prime number
# 4172653 is pandigit & prime number
# 4175263 is pandigit & prime number
# 4176253 is pandigit & prime number
# 4213567 is pandigit & prime number
# 4216573 is pandigit & prime number
# 4216753 is pandigit & prime number
# 4231567 is pandigit & prime number
# 4235761 is pandigit & prime number
# 4253167 is pandigit & prime number
# 4253617 is pandigit & prime number
# 4253671 is pandigit & prime number
# 4257163 is pandigit & prime number
# 4257613 is pandigit & prime number
# 4261357 is pandigit & prime number
# 4263157 is pandigit & prime number
# 4265137 is pandigit & prime number
# 4265713 is pandigit & prime number
# 4265731 is pandigit & prime number
# 4267531 is pandigit & prime number
# 4271563 is pandigit & prime number
# 4276513 is pandigit & prime number
# 4312657 is pandigit & prime number
# 4321657 is pandigit & prime number
# 4325617 is pandigit & prime number
# 4326571 is pandigit & prime number
# 4356217 is pandigit & prime number
# 4356721 is pandigit & prime number
# 4361257 is pandigit & prime number
# 4362751 is pandigit & prime number
# 4365271 is pandigit & prime number
# 4372651 is pandigit & prime number
# 4375621 is pandigit & prime number
# 4513627 is pandigit & prime number
# 4516327 is pandigit & prime number
# 4521367 is pandigit & prime number
# 4521637 is pandigit & prime number
# 4523671 is pandigit & prime number
# 4526371 is pandigit & prime number
# 4527361 is pandigit & prime number
# 4537261 is pandigit & prime number
# 4561237 is pandigit & prime number
# 4561327 is pandigit & prime number
# 4561723 is pandigit & prime number
# 4562317 is pandigit & prime number
# 4562731 is pandigit & prime number
# 4563127 is pandigit & prime number
# 4563217 is pandigit & prime number
# 4563271 is pandigit & prime number
# 4567231 is pandigit & prime number
# 4571263 is pandigit & prime number
# 4572163 is pandigit & prime number
# 4621537 is pandigit & prime number
# 4625713 is pandigit & prime number
# 4631527 is pandigit & prime number
# 4637251 is pandigit & prime number
# 4652173 is pandigit & prime number
# 4652317 is pandigit & prime number
# 4657123 is pandigit & prime number
# 4657321 is pandigit & prime number
# 4672531 is pandigit & prime number
# 4675123 is pandigit & prime number
# 4712563 is pandigit & prime number
# 4716253 is pandigit & prime number
# 4721653 is pandigit & prime number
# 4723561 is pandigit & prime number
# 4725613 is pandigit & prime number
# 4725631 is pandigit & prime number
# 4732561 is pandigit & prime number
# 4752361 is pandigit & prime number
# 4765213 is pandigit & prime number
# 5123467 is pandigit & prime number
# 5126347 is pandigit & prime number
# 5126437 is pandigit & prime number
# 5136427 is pandigit & prime number
# 5142637 is pandigit & prime number
# 5143267 is pandigit & prime number
# 5146237 is pandigit & prime number
# 5162473 is pandigit & prime number
# 5162743 is pandigit & prime number
# 5164273 is pandigit & prime number
# 5164723 is pandigit & prime number
# 5172463 is pandigit & prime number
# 5176243 is pandigit & prime number
# 5214367 is pandigit & prime number
# 5214637 is pandigit & prime number
# 5214763 is pandigit & prime number
# 5216473 is pandigit & prime number
# 5231647 is pandigit & prime number
# 5234167 is pandigit & prime number
# 5236741 is pandigit & prime number
# 5237641 is pandigit & prime number
# 5241673 is pandigit & prime number
# 5243167 is pandigit & prime number
# 5243761 is pandigit & prime number
# 5246173 is pandigit & prime number
# 5246713 is pandigit & prime number
# 5247163 is pandigit & prime number
# 5261743 is pandigit & prime number
# 5263417 is pandigit & prime number
# 5264137 is pandigit & prime number
# 5264173 is pandigit & prime number
# 5267341 is pandigit & prime number
# 5267413 is pandigit & prime number
# 5271463 is pandigit & prime number
# 5274163 is pandigit & prime number
# 5274631 is pandigit & prime number
# 5276431 is pandigit & prime number
# 5312467 is pandigit & prime number
# 5321467 is pandigit & prime number
# 5321647 is pandigit & prime number
# 5327461 is pandigit & prime number
# 5341627 is pandigit & prime number
# 5342167 is pandigit & prime number
# 5342761 is pandigit & prime number
# 5346127 is pandigit & prime number
# 5347621 is pandigit & prime number
# 5361247 is pandigit & prime number
# 5364127 is pandigit & prime number
# 5367421 is pandigit & prime number
# 5376421 is pandigit & prime number
# 5421673 is pandigit & prime number
# 5421763 is pandigit & prime number
# 5423167 is pandigit & prime number
# 5423617 is pandigit & prime number
# 5426173 is pandigit & prime number
# 5426371 is pandigit & prime number
# 5426713 is pandigit & prime number
# 5431627 is pandigit & prime number
# 5436127 is pandigit & prime number
# 5436217 is pandigit & prime number
# 5436271 is pandigit & prime number
# 5436721 is pandigit & prime number
# 5461273 is pandigit & prime number
# 5461723 is pandigit & prime number
# 5462137 is pandigit & prime number
# 5462173 is pandigit & prime number
# 5463217 is pandigit & prime number
# 5463721 is pandigit & prime number
# 5472613 is pandigit & prime number
# 5472631 is pandigit & prime number
# 5473261 is pandigit & prime number
# 5476213 is pandigit & prime number
# 5614327 is pandigit & prime number
# 5621437 is pandigit & prime number
# 5624137 is pandigit & prime number
# 5624317 is pandigit & prime number
# 5624713 is pandigit & prime number
# 5627143 is pandigit & prime number
# 5631427 is pandigit & prime number
# 5632741 is pandigit & prime number
# 5634217 is pandigit & prime number
# 5634721 is pandigit & prime number
# 5641327 is pandigit & prime number
# 5643217 is pandigit & prime number
# 5647231 is pandigit & prime number
# 5647321 is pandigit & prime number
# 5672341 is pandigit & prime number
# 5672413 is pandigit & prime number
# 5674231 is pandigit & prime number
# 5723461 is pandigit & prime number
# 5724163 is pandigit & prime number
# 5724613 is pandigit & prime number
# 5726143 is pandigit & prime number
# 5726341 is pandigit & prime number
# 5734621 is pandigit & prime number
# 5742361 is pandigit & prime number
# 5742631 is pandigit & prime number
# 5746123 is pandigit & prime number
# 5746231 is pandigit & prime number
# 5761423 is pandigit & prime number
# 5762143 is pandigit & prime number
# 5762413 is pandigit & prime number
# 5763421 is pandigit & prime number
# 6124753 is pandigit & prime number
# 6134257 is pandigit & prime number
# 6142573 is pandigit & prime number
# 6145273 is pandigit & prime number
# 6145327 is pandigit & prime number
# 6145723 is pandigit & prime number
# 6152743 is pandigit & prime number
# 6154273 is pandigit & prime number
# 6154723 is pandigit & prime number
# 6174253 is pandigit & prime number
# 6175243 is pandigit & prime number
# 6175423 is pandigit & prime number
# 6214357 is pandigit & prime number
# 6214573 is pandigit & prime number
# 6214753 is pandigit & prime number
# 6215347 is pandigit & prime number
# 6217543 is pandigit & prime number
# 6234517 is pandigit & prime number
# 6235147 is pandigit & prime number
# 6235417 is pandigit & prime number
# 6235741 is pandigit & prime number
# 6241537 is pandigit & prime number
# 6243157 is pandigit & prime number
# 6245731 is pandigit & prime number
# 6251347 is pandigit & prime number
# 6251743 is pandigit & prime number
# 6257143 is pandigit & prime number
# 6257431 is pandigit & prime number
# 6274531 is pandigit & prime number
# 6275341 is pandigit & prime number
# 6312547 is pandigit & prime number
# 6321457 is pandigit & prime number
# 6325471 is pandigit & prime number
# 6342157 is pandigit & prime number
# 6342517 is pandigit & prime number
# 6345127 is pandigit & prime number
# 6345271 is pandigit & prime number
# 6345721 is pandigit & prime number
# 6347521 is pandigit & prime number
# 6352147 is pandigit & prime number
# 6352741 is pandigit & prime number
# 6354217 is pandigit & prime number
# 6415237 is pandigit & prime number
# 6421573 is pandigit & prime number
# 6423517 is pandigit & prime number
# 6423751 is pandigit & prime number
# 6435127 is pandigit & prime number
# 6435721 is pandigit & prime number
# 6437521 is pandigit & prime number
# 6451723 is pandigit & prime number
# 6452137 is pandigit & prime number
# 6453721 is pandigit & prime number
# 6457123 is pandigit & prime number
# 6472351 is pandigit & prime number
# 6472513 is pandigit & prime number
# 6473251 is pandigit & prime number
# 6475321 is pandigit & prime number
# 6512347 is pandigit & prime number
# 6512437 is pandigit & prime number
# 6513427 is pandigit & prime number
# 6514327 is pandigit & prime number
# 6524137 is pandigit & prime number
# 6527413 is pandigit & prime number
# 6541723 is pandigit & prime number
# 6542713 is pandigit & prime number
# 6543127 is pandigit & prime number
# 6547213 is pandigit & prime number
# 6572143 is pandigit & prime number
# 6572413 is pandigit & prime number
# 6572431 is pandigit & prime number
# 6574231 is pandigit & prime number
# 6714523 is pandigit & prime number
# 6724351 is pandigit & prime number
# 6725143 is pandigit & prime number
# 6732541 is pandigit & prime number
# 6734521 is pandigit & prime number
# 6745231 is pandigit & prime number
# 6751243 is pandigit & prime number
# 6754213 is pandigit & prime number
# 7124653 is pandigit & prime number
# 7125463 is pandigit & prime number
# 7126453 is pandigit & prime number
# 7126543 is pandigit & prime number
# 7142563 is pandigit & prime number
# 7145623 is pandigit & prime number
# 7152643 is pandigit & prime number
# 7164253 is pandigit & prime number
# 7165423 is pandigit & prime number
# 7215643 is pandigit & prime number
# 7216453 is pandigit & prime number
# 7216543 is pandigit & prime number
# 7234651 is pandigit & prime number
# 7245361 is pandigit & prime number
# 7246513 is pandigit & prime number
# 7253461 is pandigit & prime number
# 7253641 is pandigit & prime number
# 7256341 is pandigit & prime number
# 7264351 is pandigit & prime number
# 7264513 is pandigit & prime number
# 7264531 is pandigit & prime number
# 7324561 is pandigit & prime number
# 7324651 is pandigit & prime number
# 7352461 is pandigit & prime number
# 7354261 is pandigit & prime number
# 7356421 is pandigit & prime number
# 7362541 is pandigit & prime number
# 7412563 is pandigit & prime number
# 7412653 is pandigit & prime number
# 7415623 is pandigit & prime number
# 7421563 is pandigit & prime number
# 7425361 is pandigit & prime number
# 7425631 is pandigit & prime number
# 7426351 is pandigit & prime number
# 7432651 is pandigit & prime number
# 7435621 is pandigit & prime number
# 7451263 is pandigit & prime number
# 7451623 is pandigit & prime number
# 7452163 is pandigit & prime number
# 7456231 is pandigit & prime number
# 7456321 is pandigit & prime number
# 7462513 is pandigit & prime number
# 7514623 is pandigit & prime number
# 7524631 is pandigit & prime number
# 7526143 is pandigit & prime number
# 7536241 is pandigit & prime number
# 7536421 is pandigit & prime number
# 7541623 is pandigit & prime number
# 7542163 is pandigit & prime number
# 7546321 is pandigit & prime number
# 7561423 is pandigit & prime number
# 7562341 is pandigit & prime number
# 7562413 is pandigit & prime number
# 7562431 is pandigit & prime number
# 7564231 is pandigit & prime number
# 7621543 is pandigit & prime number
# 7624531 is pandigit & prime number
# 7625143 is pandigit & prime number
# 7625341 is pandigit & prime number
# 7641253 is pandigit & prime number
# 7642513 is pandigit & prime number
# 7652413 is pandigit & prime number
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-61c1fba7f54e> in <module>()
#       1 number = 1
#       2 while True:
# ----> 3     if is_pandigit(number):
#       4         #print("pandigital number",number)
#       5         if is_prime(number):
#
# <ipython-input-11-01f660e6b618> in is_pandigit(num)
#       2 def is_pandigit(num):
#       3     string=str(num)
# ----> 4     for i in range(1,len(string)+1):
#       5         if not str(i) in string:
#       6             return False
#
# KeyboardInterrupt:
