# %% [markdown]
# 일요일의 갯수(매달 1일이 일요일이고, 20세기동안(1 Jan 1901 to 31 Dec 2000))

# %% [markdown]
# Q019
#
# You are given the following information, but you may prefer to do some research for yourself.
#
#     1 Jan 1900 was a Monday.
#     Thirty days has September,
#     April, June and November.
#     All the rest have thirty-one,
#     Saving February alone,
#     Which has twenty-eight, rain or shine.
#     And on leap years, twenty-nine.
#     A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
#
# How many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?

# %%
months = 'Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec'
days = [31,28,31,30,31,30,31,31,30,31,30,31]
calendar = dict(zip(months.split(),days))
print(calendar)
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30, 'Jul': 31, 'Aug': 31, 'Sep': 30, 'Oct': 31, 'Nov': 30, 'Dec': 31}

# %%
days = [31,28,31,30,31,30,31,31,30,31,30,31]
cal = dict(zip(range(1,13),days))
print(cal)
# Out:
# {1: 31, 2: 28, 3: 31, 4: 30, 5: 31, 6: 30, 7: 31, 8: 31, 9: 30, 10: 31, 11: 30, 12: 31}

# %%
daylist = [31,28,31,30,31,30,31,31,30,31,30,31]
total=0

for y in range(1900,2001):
    for m in range(12):
        for d in range(daylist[m]):
            total+=1

print(total)
# Out:
# 36865

# %%
daylist = [31,28,31,30,31,30,31,31,30,31,30,31]
total=0

for y in range(1900,2001):
    for m in range(12):
        day=daylist[m]
        if y%4==0 and m==1: 
            day+=1
        for d in range(day):
            total+=1

print(total)
# Out:
# 36891

# %%
daylist = [31,28,31,30,31,30,31,31,30,31,30,31]
total=0

for y in range(1900,2001):
    for m in range(12):
        day=daylist[m]
        if y%4==0 and m==1: 
            day+=1
        for d in range(day):
            if total%7==6:
                print(y,m+1,d+1)
            total+=1

print(total)
# Out:
# 1900 1 7
# 1900 1 14
# 1900 1 21
# 1900 1 28
# 1900 2 4
# 1900 2 11
# 1900 2 18
# 1900 2 25
# 1900 3 3
# 1900 3 10
# 1900 3 17
# 1900 3 24
# 1900 3 31
# 1900 4 7
# 1900 4 14
# 1900 4 21
# 1900 4 28
# 1900 5 5
# 1900 5 12
# 1900 5 19
# 1900 5 26
# 1900 6 2
# 1900 6 9
# 1900 6 16
# 1900 6 23
# 1900 6 30
# 1900 7 7
# 1900 7 14
# 1900 7 21
# 1900 7 28
# 1900 8 4
# 1900 8 11
# 1900 8 18
# 1900 8 25
# 1900 9 1
# 1900 9 8
# 1900 9 15
# 1900 9 22
# 1900 9 29
# 1900 10 6
# 1900 10 13
# 1900 10 20
# 1900 10 27
# 1900 11 3
# 1900 11 10
# 1900 11 17
# 1900 11 24
# 1900 12 1
# 1900 12 8
# 1900 12 15
# 1900 12 22
# 1900 12 29
# 1901 1 5
# 1901 1 12
# 1901 1 19
# 1901 1 26
# 1901 2 2
# 1901 2 9
# 1901 2 16
# 1901 2 23
# 1901 3 2
# 1901 3 9
# 1901 3 16
# 1901 3 23
# 1901 3 30
# 1901 4 6
# 1901 4 13
# 1901 4 20
# 1901 4 27
# 1901 5 4
# 1901 5 11
# 1901 5 18
# 1901 5 25
# 1901 6 1
# 1901 6 8
# 1901 6 15
# 1901 6 22
# 1901 6 29
# 1901 7 6
# 1901 7 13
# 1901 7 20
# 1901 7 27
# 1901 8 3
# 1901 8 10
# ...

# %%
daylist = [31,28,31,30,31,30,31,31,30,31,30,31]
total=0
count=0

for y in range(1900,2001):
    for m in range(12):
        day=daylist[m]
        if y%4==0 and m==1: 
            day+=1
        for d in range(day):
            if y>1900 and d==0 and total%7==6:
                count+=1
            total+=1

print(total,count)
# Out:
# 36891 171

# %%
daylist = [31,28,31,30,31,30,31,31,30,31,30,31]
total=0
count=0
for y in range(1900,2001):
    for m in range(12):
        day=daylist[m]
        if y%4==0 and m==1: 
            day+=1
        for d in range(day):
            #print(y,m+1,d+1,total,total%7)
            if y>1900 and d==0 and total%7==6:
                count+=1
                #print(y,m+1,d+1,total,total%7,'******')
            total+=1

print(count)
# Out:
# 36891 171

# %%
from datetime import datetime
from datetime import date
print(datetime(2000,1,1))
print(datetime.today())
print(datetime.now())
print(date(1901,1,1).weekday())
print(datetime)
# Out:
# 2000-01-01 00:00:00
# 2018-09-13 18:24:36.738822
# 2018-09-13 18:24:36.738822
# 1

# %%
from datetime import date

start_date = date(2013, 1, 1)
end_date = date(2015, 6, 2)
for single_date in daterange(start_date, end_date):
    print single_date.strftime("%Y-%m-%d")

# %% [markdown]
# ## old =========

# %%
# Month list
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
for month in months:
    print(month)
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
# Sep
# Oct
# Nov
# Dec

# %%
# Month list(tuple)
months = ('Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec')
for month in months:
    print(month)
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
# Sep
# Oct
# Nov
# Dec

# %%
# Month List (named list)
months = [('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)]
for month in months:
    print(month,month[0],month[1])
# Out:
# ('Jan', 30) Jan , 30
# ('Feb', 28) Feb , 28
# ('Mar', 31) Mar , 31
# ('Apr', 30) Apr , 30
# ('May', 31) May , 31
# ('Jun', 30) Jun , 30
# ('Jul', 31) Jul , 31
# ('Aug', 31) Aug , 31
# ('Sep', 30) Sep , 30
# ('Oct', 31) Oct , 31
# ('Nov', 30) Nov , 30
# ('Dec', 31) Dec , 31

# %%
# Month List (dictionary)
months = {('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)}
for month in months:
    print(month,month[0],month[1])
# Out:
# ('Dec', 31) Dec 31
# ('Nov', 30) Nov 30
# ('Feb', 28) Feb 28
# ('Jul', 31) Jul 31
# ('Aug', 31) Aug 31
# ('May', 31) May 31
# ('Mar', 31) Mar 31
# ('Jun', 30) Jun 30
# ('Sep', 30) Sep 30
# ('Oct', 31) Oct 31
# ('Jan', 31) Jan 31
# ('Apr', 30) Apr 30

# %%
# Year range
for year in range(1900,2001):
    print(year)
# Out:
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000

# %%
# 전체 년월
months = [('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)]
for year in range(1900,2001):
    for month in months:
        print(year,month[0],month[1])
# Out:
# 1900 Jan 31
# 1900 Feb 28
# 1900 Mar 31
# 1900 Apr 30
# 1900 May 31
# 1900 Jun 30
# 1900 Jul 31
# 1900 Aug 31
# 1900 Sep 30
# 1900 Oct 31
# 1900 Nov 30
# 1900 Dec 31
# 1901 Jan 31
# 1901 Feb 28
# 1901 Mar 31
# 1901 Apr 30
# 1901 May 31
# 1901 Jun 30
# 1901 Jul 31
# 1901 Aug 31
# 1901 Sep 30
# 1901 Oct 31
# 1901 Nov 30
# 1901 Dec 31
# 1902 Jan 31
# 1902 Feb 28
# 1902 Mar 31
# 1902 Apr 30
# 1902 May 31
# 1902 Jun 30
# 1902 Jul 31
# 1902 Aug 31
# 1902 Sep 30
# 1902 Oct 31
# 1902 Nov 30
# 1902 Dec 31
# 1903 Jan 31
# 1903 Feb 28
# 1903 Mar 31
# 1903 Apr 30
# 1903 May 31
# 1903 Jun 30
# 1903 Jul 31
# 1903 Aug 31
# 1903 Sep 30
# 1903 Oct 31
# 1903 Nov 30
# 1903 Dec 31
# 1904 Jan 31
# 1904 Feb 28
# 1904 Mar 31
# 1904 Apr 30
# 1904 May 31
# 1904 Jun 30
# 1904 Jul 31
# 1904 Aug 31
# 1904 Sep 30
# 1904 Oct 31
# 1904 Nov 30
# 1904 Dec 31
# 1905 Jan 31
# 1905 Feb 28
# 1905 Mar 31
# 1905 Apr 30
# 1905 May 31
# 1905 Jun 30
# 1905 Jul 31
# 1905 Aug 31
# 1905 Sep 30
# 1905 Oct 31
# 1905 Nov 30
# ...

# %%
# 전체 년월(dictionary)
months = {('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)}
for year in range(1900,2001):
    for month in months:
        print(year,month[0],month[1])
# Out:
# 1900 Dec 31
# 1900 Nov 30
# 1900 Feb 28
# 1900 Jul 31
# 1900 Aug 31
# 1900 May 31
# 1900 Mar 31
# 1900 Jun 30
# 1900 Sep 30
# 1900 Oct 31
# 1900 Jan 31
# 1900 Apr 30
# 1901 Dec 31
# 1901 Nov 30
# 1901 Feb 28
# 1901 Jul 31
# 1901 Aug 31
# 1901 May 31
# 1901 Mar 31
# 1901 Jun 30
# 1901 Sep 30
# 1901 Oct 31
# 1901 Jan 31
# 1901 Apr 30
# 1902 Dec 31
# 1902 Nov 30
# 1902 Feb 28
# 1902 Jul 31
# 1902 Aug 31
# 1902 May 31
# 1902 Mar 31
# 1902 Jun 30
# 1902 Sep 30
# 1902 Oct 31
# 1902 Jan 31
# 1902 Apr 30
# 1903 Dec 31
# 1903 Nov 30
# 1903 Feb 28
# 1903 Jul 31
# 1903 Aug 31
# 1903 May 31
# 1903 Mar 31
# 1903 Jun 30
# 1903 Sep 30
# 1903 Oct 31
# 1903 Jan 31
# 1903 Apr 30
# 1904 Dec 31
# 1904 Nov 30
# 1904 Feb 28
# 1904 Jul 31
# 1904 Aug 31
# 1904 May 31
# 1904 Mar 31
# 1904 Jun 30
# 1904 Sep 30
# 1904 Oct 31
# 1904 Jan 31
# 1904 Apr 30
# 1905 Dec 31
# 1905 Nov 30
# 1905 Feb 28
# 1905 Jul 31
# 1905 Aug 31
# 1905 May 31
# 1905 Mar 31
# 1905 Jun 30
# 1905 Sep 30
# 1905 Oct 31
# 1905 Jan 31
# ...

# %%
# 윤달 계산
months = [('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)]
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
        else :
            print(year,month[0],month[1])
# Out:
# 1900 Jan 31
# 1900 Feb 28
# 1900 Mar 31
# 1900 Apr 30
# 1900 May 31
# 1900 Jun 30
# 1900 Jul 31
# 1900 Aug 31
# 1900 Sep 30
# 1900 Oct 31
# 1900 Nov 30
# 1900 Dec 31
# 1901 Jan 31
# 1901 Feb 28
# 1901 Mar 31
# 1901 Apr 30
# 1901 May 31
# 1901 Jun 30
# 1901 Jul 31
# 1901 Aug 31
# 1901 Sep 30
# 1901 Oct 31
# 1901 Nov 30
# 1901 Dec 31
# 1902 Jan 31
# 1902 Feb 28
# 1902 Mar 31
# 1902 Apr 30
# 1902 May 31
# 1902 Jun 30
# 1902 Jul 31
# 1902 Aug 31
# 1902 Sep 30
# 1902 Oct 31
# 1902 Nov 30
# 1902 Dec 31
# 1903 Jan 31
# 1903 Feb 28
# 1903 Mar 31
# 1903 Apr 30
# 1903 May 31
# 1903 Jun 30
# 1903 Jul 31
# 1903 Aug 31
# 1903 Sep 30
# 1903 Oct 31
# 1903 Nov 30
# 1903 Dec 31
# 1904 Jan 31
# 1904 Feb 29 leap year
# 1904 Mar 31
# 1904 Apr 30
# 1904 May 31
# 1904 Jun 30
# 1904 Jul 31
# 1904 Aug 31
# 1904 Sep 30
# 1904 Oct 31
# 1904 Nov 30
# 1904 Dec 31
# 1905 Jan 31
# 1905 Feb 28
# 1905 Mar 31
# 1905 Apr 30
# 1905 May 31
# 1905 Jun 30
# 1905 Jul 31
# 1905 Aug 31
# 1905 Sep 30
# 1905 Oct 31
# ...

# %%
# 윤달 계산(dict)
months = {('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)}
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
        else :
            print(year,month[0],month[1])
# Out:
# 1900 Dec 31
# 1900 Nov 30
# 1900 Feb 28
# 1900 Jul 31
# 1900 Aug 31
# 1900 May 31
# 1900 Mar 31
# 1900 Jun 30
# 1900 Sep 30
# 1900 Oct 31
# 1900 Jan 31
# 1900 Apr 30
# 1901 Dec 31
# 1901 Nov 30
# 1901 Feb 28
# 1901 Jul 31
# 1901 Aug 31
# 1901 May 31
# 1901 Mar 31
# 1901 Jun 30
# 1901 Sep 30
# 1901 Oct 31
# 1901 Jan 31
# 1901 Apr 30
# 1902 Dec 31
# 1902 Nov 30
# 1902 Feb 28
# 1902 Jul 31
# 1902 Aug 31
# 1902 May 31
# 1902 Mar 31
# 1902 Jun 30
# 1902 Sep 30
# 1902 Oct 31
# 1902 Jan 31
# 1902 Apr 30
# 1903 Dec 31
# 1903 Nov 30
# 1903 Feb 28
# 1903 Jul 31
# 1903 Aug 31
# 1903 May 31
# 1903 Mar 31
# 1903 Jun 30
# 1903 Sep 30
# 1903 Oct 31
# 1903 Jan 31
# 1903 Apr 30
# 1904 Dec 31
# 1904 Nov 30
# 1904 Feb 29 leap year
# 1904 Jul 31
# 1904 Aug 31
# 1904 May 31
# 1904 Mar 31
# 1904 Jun 30
# 1904 Sep 30
# 1904 Oct 31
# 1904 Jan 31
# 1904 Apr 30
# 1905 Dec 31
# 1905 Nov 30
# 1905 Feb 28
# 1905 Jul 31
# 1905 Aug 31
# 1905 May 31
# 1905 Mar 31
# 1905 Jun 30
# 1905 Sep 30
# 1905 Oct 31
# ...

# %%
# 1일이 일요일인 달수 계산 #1
sundayCount = 0
totalDay = 0
months = [('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)]
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
            totalDay=totalDay+month[1]+1
        else :
            print(year,month[0],month[1])
            totalDay=totalDay+month[1]
        print(totalDay,(totalDay-6)%7)
# 날짜의 누적합이 7로 나누어 떨어질때마다, 매월1일에 일요일이 걸리는 것으로 판단, 
# 1900년 1월1일이 월요일이기 때문에, 초기값은 -6
# Out:
# 1900 Jan 31
# 31 4
# 1900 Feb 28
# 59 4
# 1900 Mar 31
# 90 0
# 1900 Apr 30
# 120 2
# 1900 May 31
# 151 5
# 1900 Jun 30
# 181 0
# 1900 Jul 31
# 212 3
# 1900 Aug 31
# 243 6
# 1900 Sep 30
# 273 1
# 1900 Oct 31
# 304 4
# 1900 Nov 30
# 334 6
# 1900 Dec 31
# 365 2
# 1901 Jan 31
# 396 5
# 1901 Feb 28
# 424 5
# 1901 Mar 31
# 455 1
# 1901 Apr 30
# 485 3
# 1901 May 31
# 516 6
# 1901 Jun 30
# 546 1
# 1901 Jul 31
# 577 4
# 1901 Aug 31
# 608 0
# 1901 Sep 30
# 638 2
# 1901 Oct 31
# 669 5
# 1901 Nov 30
# 699 0
# 1901 Dec 31
# 730 3
# 1902 Jan 31
# 761 6
# 1902 Feb 28
# 789 6
# 1902 Mar 31
# 820 2
# 1902 Apr 30
# 850 4
# 1902 May 31
# 881 0
# 1902 Jun 30
# 911 2
# 1902 Jul 31
# 942 5
# 1902 Aug 31
# 973 1
# 1902 Sep 30
# 1003 3
# 1902 Oct 31
# 1034 6
# 1902 Nov 30
# 1064 1
# 1902 Dec 31
# 1095 4
# 1903 Jan 31
# 1126 0
# 1903 Feb 28
# 1154 0
# 1903 Mar 31
# 1185 3
# 1903 Apr 30
# 1215 5
# 1903 May 31
# 1246 1
# 1903 Jun 30
# 1276 3
# 1903 Jul 31
# 1307 6
# 1903 Aug 31
# 1338 2
# 1903 Sep 30
# 1368 4
# ...

# %%
# 1일이 일요일인 달수 계산 #1(dict)
sundayCount = 0
totalDay = 0
months = {('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)}
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
            totalDay=totalDay+month[1]+1
        else :
            print(year,month[0],month[1])
            totalDay=totalDay+month[1]
        print(totalDay,(totalDay-6)%7)
# 날짜의 누적합이 7로 나누어 떨어질때마다, 매월1일에 일요일이 걸리는 것으로 판단, 
# 1900년 1월1일이 월요일이기 때문에, 초기값은 -6
# Out:
# 1900 Dec 31
# 31 4
# 1900 Nov 30
# 61 6
# 1900 Feb 28
# 89 6
# 1900 Jul 31
# 120 2
# 1900 Aug 31
# 151 5
# 1900 May 31
# 182 1
# 1900 Mar 31
# 213 4
# 1900 Jun 30
# 243 6
# 1900 Sep 30
# 273 1
# 1900 Oct 31
# 304 4
# 1900 Jan 31
# 335 0
# 1900 Apr 30
# 365 2
# 1901 Dec 31
# 396 5
# 1901 Nov 30
# 426 0
# 1901 Feb 28
# 454 0
# 1901 Jul 31
# 485 3
# 1901 Aug 31
# 516 6
# 1901 May 31
# 547 2
# 1901 Mar 31
# 578 5
# 1901 Jun 30
# 608 0
# 1901 Sep 30
# 638 2
# 1901 Oct 31
# 669 5
# 1901 Jan 31
# 700 1
# 1901 Apr 30
# 730 3
# 1902 Dec 31
# 761 6
# 1902 Nov 30
# 791 1
# 1902 Feb 28
# 819 1
# 1902 Jul 31
# 850 4
# 1902 Aug 31
# 881 0
# 1902 May 31
# 912 3
# 1902 Mar 31
# 943 6
# 1902 Jun 30
# 973 1
# 1902 Sep 30
# 1003 3
# 1902 Oct 31
# 1034 6
# 1902 Jan 31
# 1065 2
# 1902 Apr 30
# 1095 4
# 1903 Dec 31
# 1126 0
# 1903 Nov 30
# 1156 2
# 1903 Feb 28
# 1184 2
# 1903 Jul 31
# 1215 5
# 1903 Aug 31
# 1246 1
# 1903 May 31
# 1277 4
# 1903 Mar 31
# 1308 0
# 1903 Jun 30
# 1338 2
# 1903 Sep 30
# 1368 4
# ...

# %%
# 1일이 일요일인 달수 계산 #2
sundayCount = 0
totalDay = 0
months = [('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)]
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
            totalDay=totalDay+month[1]+1
        else :
            print(year,month[0],month[1])
            totalDay=totalDay+month[1]
        print(totalDay,(totalDay-6)%7)
        if (totalDay-6)%7 == 0 and year>1900:
            sundayCount+=1
print(sundayCount)
print(sundayCount-1) 
#마지막 2000년 12월이 7로 나누어 떨어지는데, 2001년 1월1일이 카운트에 들어가서 1을 빼줌.
# Out:
# 1900 Jan 31
# 31 4
# 1900 Feb 28
# 59 4
# 1900 Mar 31
# 90 0
# 1900 Apr 30
# 120 2
# 1900 May 31
# 151 5
# 1900 Jun 30
# 181 0
# 1900 Jul 31
# 212 3
# 1900 Aug 31
# 243 6
# 1900 Sep 30
# 273 1
# 1900 Oct 31
# 304 4
# 1900 Nov 30
# 334 6
# 1900 Dec 31
# 365 2
# 1901 Jan 31
# 396 5
# 1901 Feb 28
# 424 5
# 1901 Mar 31
# 455 1
# 1901 Apr 30
# 485 3
# 1901 May 31
# 516 6
# 1901 Jun 30
# 546 1
# 1901 Jul 31
# 577 4
# 1901 Aug 31
# 608 0
# 1901 Sep 30
# 638 2
# 1901 Oct 31
# 669 5
# 1901 Nov 30
# 699 0
# 1901 Dec 31
# 730 3
# 1902 Jan 31
# 761 6
# 1902 Feb 28
# 789 6
# 1902 Mar 31
# 820 2
# 1902 Apr 30
# 850 4
# 1902 May 31
# 881 0
# 1902 Jun 30
# 911 2
# 1902 Jul 31
# 942 5
# 1902 Aug 31
# 973 1
# 1902 Sep 30
# 1003 3
# 1902 Oct 31
# 1034 6
# 1902 Nov 30
# 1064 1
# 1902 Dec 31
# 1095 4
# 1903 Jan 31
# 1126 0
# 1903 Feb 28
# 1154 0
# 1903 Mar 31
# 1185 3
# 1903 Apr 30
# 1215 5
# 1903 May 31
# 1246 1
# 1903 Jun 30
# 1276 3
# 1903 Jul 31
# 1307 6
# 1903 Aug 31
# 1338 2
# 1903 Sep 30
# 1368 4
# ...

# %%
# 1일이 일요일인 달수 계산 #2(dict)
sundayCount = 0
totalDay = 0
months = {('Jan',31),('Feb',28),('Mar',31),('Apr',30),('May',31),('Jun',30),('Jul',31),('Aug',31),('Sep',30),('Oct',31),('Nov',30),('Dec',31)}
for year in range(1900,2001):
    for month in months:
        if month[0]=='Feb' and year%4==0 and year%100!=0:
            print(year,month[0],month[1]+1,"leap year")
            totalDay=totalDay+month[1]+1
        else :
            print(year,month[0],month[1])
            totalDay=totalDay+month[1]
        print(totalDay,(totalDay-6)%7)
        if (totalDay-6)%7 == 0 and year>1900:
            sundayCount+=1
print(sundayCount)
print(sundayCount-1) 
#마지막 2000년 12월이 7로 나누어 떨어지는데, 2001년 1월1일이 카운트에 들어가서 1을 빼줌.
# Out:
# 1900 Dec 31
# 31 4
# 1900 Nov 30
# 61 6
# 1900 Feb 28
# 89 6
# 1900 Jul 31
# 120 2
# 1900 Aug 31
# 151 5
# 1900 May 31
# 182 1
# 1900 Mar 31
# 213 4
# 1900 Jun 30
# 243 6
# 1900 Sep 30
# 273 1
# 1900 Oct 31
# 304 4
# 1900 Jan 31
# 335 0
# 1900 Apr 30
# 365 2
# 1901 Dec 31
# 396 5
# 1901 Nov 30
# 426 0
# 1901 Feb 28
# 454 0
# 1901 Jul 31
# 485 3
# 1901 Aug 31
# 516 6
# 1901 May 31
# 547 2
# 1901 Mar 31
# 578 5
# 1901 Jun 30
# 608 0
# 1901 Sep 30
# 638 2
# 1901 Oct 31
# 669 5
# 1901 Jan 31
# 700 1
# 1901 Apr 30
# 730 3
# 1902 Dec 31
# 761 6
# 1902 Nov 30
# 791 1
# 1902 Feb 28
# 819 1
# 1902 Jul 31
# 850 4
# 1902 Aug 31
# 881 0
# 1902 May 31
# 912 3
# 1902 Mar 31
# 943 6
# 1902 Jun 30
# 973 1
# 1902 Sep 30
# 1003 3
# 1902 Oct 31
# 1034 6
# 1902 Jan 31
# 1065 2
# 1902 Apr 30
# 1095 4
# 1903 Dec 31
# 1126 0
# 1903 Nov 30
# 1156 2
# 1903 Feb 28
# 1184 2
# 1903 Jul 31
# 1215 5
# 1903 Aug 31
# 1246 1
# 1903 May 31
# 1277 4
# 1903 Mar 31
# 1308 0
# 1903 Jun 30
# 1338 2
# 1903 Sep 30
# 1368 4
# ...

# %%
#forum-1
def monthDays(x, y):
	if y % 4 != 0:
		switcher =  {
			 1: 31,
			 2: 28,
			 3: 31,
			 4: 30,
			 5: 31,
			 6: 30,
			 7: 31,
			 8: 31,
			 9: 30,
			 10: 31,
			 11: 30,
			 12: 31
		}
	else:
		switcher =  {
			 1: 31,
			 2: 29,
			 3: 31,
			 4: 30,
			 5: 31,
			 6: 30,
			 7: 31,
			 8: 31,
			 9: 30,
			 10: 31,
			 11: 30,
			 12: 31
		}
	return switcher.get(x)

def firstSun():
	count = 0
	d = 2
	for i in range(1901, 2001):
		for j in range(1, 13):
			d = (d + monthDays(j,i)%7)%7
			if d == 0: count += 1
	return count

# %%
#forum-2

import datetime

def GetDay(intDay):
    StartDate = datetime.date(1901,1,1)
    EndDate = datetime.date(2001,1,1)
    Ordinal_Start = StartDate.toordinal()
    Ordinal_End = EndDate.toordinal()
    Dayz = 0

    for i in range(Ordinal_Start,Ordinal_End):
        day = datetime.date.fromordinal(i)
        if (day.weekday() == (intDay - 1)) and (day.day == 1):
            Dayz += 1

    return Dayz

# %%
#forum-3
import pandas as pds

RANGE = pds.date_range(start='1/1/1901', end='12/31/2000')
count = 0
for date in RANGE:
    if date.day == 1 and date.weekday() == 6:
        count+=1
print(count)

# %%
#forum-4
months = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
first_day = 1     # first day of the month (initially Monday)
count = 0

for i in xrange(101):
    for j in months:
        if first_day % 7 == 0:            # checking if first day is Sunday
            count += 1
        if i % 4 == 0 and j == 28 and i != 0:  # leap year
            first_day += (j + 1) % 7
        else:
            first_day += j % 7            # calculating first day of next month
print count - 2     # subtract 2 because the year 1900 has two Sundays at the beginning of the 
                    # month, but the question is asking from Jan 1901.

# %%
#forum-5
import datetime 

def Euler_19():
    year = 1901
    sundays = 0
    for i in range(year, 2001):
        for j in range(1, 13):
            d = datetime.date(i, j, 1)
            if d.weekday() == 6:
                sundays += 1
    return sundays

# %%
#forum-6
import calendar

cal = calendar.Calendar(6)

sum = 0
for year in range(1901, 2001):
    for month in range(1,13):
        if (1,6) in cal.monthdays2calendar(year,month)[0]:
            sum += 1

print(sum)

# %%
#forum-7
from datetime import date
sundays = []
for year in range(1901,2000+1):
  for month in range(1,12+1):
    sundays.append(date(year,month,1).weekday())
print(sun.count(6))

# %%
#forum-8
from datetime import date
import pandas as pd

if __name__ == '__main__':
	myset = set()
	startdate = date(1901, 1, 1)
	enddate = date(2000, 12, 31)
	datelist = pd.date_range(startdate, enddate).tolist()
	myset = {x for x in datelist if x.isoweekday()==7 and x.day==1}
	print(len(myset))
