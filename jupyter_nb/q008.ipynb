# %% [markdown]
# # Q008 Largest product in a series
#
# The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
#
# >>73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450
#
# Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?
#
# download link from github
# https://raw.githubusercontent.com/nomadlife/project-euler/master/q008_data.txt
#
# open link from github
# https://github.com/nomadlife/project-euler/blob/master/q008_data.txt

# %%
from urllib.request import urlretrieve
urlretrieve("https://raw.githubusercontent.com/nomadlife/project-euler/master/q008_data.txt", "q008_data.txt")

# %%
with open("q008_data.txt") as file_object:
    lines = file_object.readlines()

# %%
string=''
for line in lines:
    string=string+line.rstrip()
print(string)
# Out:
# ...

# %%
# 13자리 숫자 출력
for i in range(0,1000):
    print(string[i:i+13])
# Out:
# 7316717653133
# 3167176531330
# 1671765313306
# 6717653133062
# 7176531330624
# 1765313306249
# 7653133062491
# 6531330624919
# 5313306249192
# 3133062491922
# 1330624919225
# 3306249192251
# 3062491922511
# 0624919225119
# 6249192251196
# 2491922511967
# 4919225119674
# 9192251196744
# 1922511967442
# 9225119674426
# 2251196744265
# 2511967442657
# 5119674426574
# 1196744265747
# 1967442657474
# 9674426574742
# 6744265747423
# 7442657474235
# 4426574742355
# 4265747423553
# 2657474235534
# 6574742355349
# 5747423553491
# 7474235534919
# 4742355349194
# 7423553491949
# 4235534919493
# 2355349194934
# 3553491949349
# 5534919493496
# 5349194934969
# 3491949349698
# 4919493496983
# 9194934969835
# 1949349698352
# 9493496983520
# 4934969835203
# 9349698352031
# 3496983520312
# 4969835203127
# 9698352031277
# 6983520312774
# 9835203127745
# 8352031277450
# 3520312774506
# 5203127745063
# 2031277450632
# 0312774506326
# 3127745063262
# 1277450632623
# 2774506326239
# 7745063262395
# ...

# %%
# 13자리 곱 계산 
for i in range(0,1000):
    product =1
    for j in string[i:i+13]:
        product = product * int(j)
    print(string[i:i+13],product)
# Out:
# 7316717653133 5000940
# 3167176531330 0
# 1671765313306 0
# 6717653133062 0
# 7176531330624 0
# 1765313306249 0
# 7653133062491 0
# 6531330624919 0
# 5313306249192 0
# 3133062491922 0
# 1330624919225 0
# 3306249192251 0
# 3062491922511 0
# 0624919225119 0
# 6249192251196 4199040
# 2491922511967 4898880
# 4919225119674 9797760
# 9192251196744 9797760
# 1922511967442 2177280
# 9225119674426 13063680
# 2251196744265 7257600
# 2511967442657 25401600
# 5119674426574 50803200
# 1196744265747 71124480
# 1967442657474 284497920
# 9674426574742 568995840
# 6744265747423 189665280
# 7442657474235 158054400
# 4426574742355 112896000
# 4265747423553 84672000
# 2657474235534 84672000
# 6574742355349 381024000
# 5747423553491 63504000
# 7474235534919 114307200
# 4742355349194 65318400
# 7423553491949 146966400
# 4235534919493 62985600
# 2355349194934 62985600
# 3553491949349 283435200
# 5534919493496 566870400
# 5349194934969 1020366720
# 3491949349698 1632586752
# 4919493496983 1632586752
# ...

# %%
# 13자리 곱 계산 (2)
from functools import reduce
for i in range(0,1000):
    product = reduce(lambda x,y:int(x)*int(y), string[i:i+13])
    print(string[i:i+13],product)
# Out:
# 7316717653133 5000940
# 3167176531330 0
# 1671765313306 0
# 6717653133062 0
# 7176531330624 0
# 1765313306249 0
# 7653133062491 0
# 6531330624919 0
# 5313306249192 0
# 3133062491922 0
# 1330624919225 0
# 3306249192251 0
# 3062491922511 0
# 0624919225119 0
# 6249192251196 4199040
# 2491922511967 4898880
# 4919225119674 9797760
# 9192251196744 9797760
# 1922511967442 2177280
# 9225119674426 13063680
# 2251196744265 7257600
# 2511967442657 25401600
# 5119674426574 50803200
# 1196744265747 71124480
# 1967442657474 284497920
# 9674426574742 568995840
# 6744265747423 189665280
# 7442657474235 158054400
# 4426574742355 112896000
# 4265747423553 84672000
# 2657474235534 84672000
# 6574742355349 381024000
# 5747423553491 63504000
# 7474235534919 114307200
# 4742355349194 65318400
# 7423553491949 146966400
# 4235534919493 62985600
# 2355349194934 62985600
# 3553491949349 283435200
# 5534919493496 566870400
# 5349194934969 1020366720
# 3491949349698 1632586752
# 4919493496983 1632586752
# ...

# %%
# 최대값 판별
maxValue =0
for i in range(0,1000):
    product =1
    for j in string[i:i+13]: 
        product = product * int(j)
    if product > maxValue:
        maxValue = product
    print(string[i:i+13],product, maxValue)
print(maxValue)
# Out:
# 7316717653133 5000940 5000940
# 3167176531330 0 5000940
# 1671765313306 0 5000940
# 6717653133062 0 5000940
# 7176531330624 0 5000940
# 1765313306249 0 5000940
# 7653133062491 0 5000940
# 6531330624919 0 5000940
# 5313306249192 0 5000940
# 3133062491922 0 5000940
# 1330624919225 0 5000940
# 3306249192251 0 5000940
# 3062491922511 0 5000940
# 0624919225119 0 5000940
# 6249192251196 4199040 5000940
# 2491922511967 4898880 5000940
# 4919225119674 9797760 9797760
# 9192251196744 9797760 9797760
# 1922511967442 2177280 9797760
# 9225119674426 13063680 13063680
# 2251196744265 7257600 13063680
# 2511967442657 25401600 25401600
# 5119674426574 50803200 50803200
# 1196744265747 71124480 71124480
# 1967442657474 284497920 284497920
# 9674426574742 568995840 568995840
# 6744265747423 189665280 568995840
# 7442657474235 158054400 568995840
# 4426574742355 112896000 568995840
# 4265747423553 84672000 568995840
# 2657474235534 84672000 568995840
# 6574742355349 381024000 568995840
# ...

# %%
# 4자리 곱 계산

with open("q008_data.txt") as file_object:
    lines = file_object.readlines()

string=''
for line in lines:
    string=string+line.rstrip()
print(string)

max_value = 0
for i in range(0,len(string)):
    print(i,":",string[i],string[i+1],string[i+2],string[i+3],end=',,,')
    product = int(string[i])*int(string[i+1])*int(string[i+2])*int(string[i+3])
    print(product)
    if product > max_value:
        max_value = product
    if i+4 == len(string):
        break
print(max_value)
# Out:
# ...
# 0 : 7 3 1 6,,,126
# 1 : 3 1 6 7,,,126
# 2 : 1 6 7 1,,,42
# 3 : 6 7 1 7,,,294
# 4 : 7 1 7 6,,,294
# 5 : 1 7 6 5,,,210
# 6 : 7 6 5 3,,,630
# 7 : 6 5 3 1,,,90
# 8 : 5 3 1 3,,,45
# 9 : 3 1 3 3,,,27
# 10 : 1 3 3 0,,,0
# 11 : 3 3 0 6,,,0
# 12 : 3 0 6 2,,,0
# 13 : 0 6 2 4,,,0
# 14 : 6 2 4 9,,,432
# 15 : 2 4 9 1,,,72
# 16 : 4 9 1 9,,,324
# 17 : 9 1 9 2,,,162
# 18 : 1 9 2 2,,,36
# 19 : 9 2 2 5,,,180
# 20 : 2 2 5 1,,,20
# 21 : 2 5 1 1,,,10
# 22 : 5 1 1 9,,,45
# 23 : 1 1 9 6,,,54
# 24 : 1 9 6 7,,,378
# 25 : 9 6 7 4,,,1512
# 26 : 6 7 4 4,,,672
# 27 : 7 4 4 2,,,224
# 28 : 4 4 2 6,,,192
# 29 : 4 2 6 5,,,240
# 30 : 2 6 5 7,,,420
# 31 : 6 5 7 4,,,840
# 32 : 5 7 4 7,,,980
# 33 : 7 4 7 4,,,784
# 34 : 4 7 4 2,,,224
# 35 : 7 4 2 3,,,168
# 36 : 4 2 3 5,,,120
# 37 : 2 3 5 5,,,150
# 38 : 3 5 5 3,,,225
# 39 : 5 5 3 4,,,300
# 40 : 5 3 4 9,,,540
# 41 : 3 4 9 1,,,108
# 42 : 4 9 1 9,,,324
# 43 : 9 1 9 4,,,324
# 44 : 1 9 4 9,,,324
# 45 : 9 4 9 3,,,972
# 46 : 4 9 3 4,,,432
# 47 : 9 3 4 9,,,972
# ...

# %%
#13자리 곱 계산

with open("q008_data.txt") as file_object:
    lines = file_object.readlines()

string=''
for line in lines:
    string=string+line.rstrip()
print(string)

max_value = 0
for i in range(0,len(string)):
    print(i,end=":")
    product =1
    for j in range(i,i+13):
        print(string[j],end=',')
        product = product * int(string[j])
    print(product)
    if product > max_value:
        max_value = product
    if i+13 == len(string):
        break
print(max_value)
# Out:
# ...
# 0:7,3,1,6,7,1,7,6,5,3,1,3,3,5000940
# 1:3,1,6,7,1,7,6,5,3,1,3,3,0,0
# 2:1,6,7,1,7,6,5,3,1,3,3,0,6,0
# 3:6,7,1,7,6,5,3,1,3,3,0,6,2,0
# 4:7,1,7,6,5,3,1,3,3,0,6,2,4,0
# 5:1,7,6,5,3,1,3,3,0,6,2,4,9,0
# 6:7,6,5,3,1,3,3,0,6,2,4,9,1,0
# 7:6,5,3,1,3,3,0,6,2,4,9,1,9,0
# 8:5,3,1,3,3,0,6,2,4,9,1,9,2,0
# 9:3,1,3,3,0,6,2,4,9,1,9,2,2,0
# 10:1,3,3,0,6,2,4,9,1,9,2,2,5,0
# 11:3,3,0,6,2,4,9,1,9,2,2,5,1,0
# 12:3,0,6,2,4,9,1,9,2,2,5,1,1,0
# 13:0,6,2,4,9,1,9,2,2,5,1,1,9,0
# 14:6,2,4,9,1,9,2,2,5,1,1,9,6,4199040
# 15:2,4,9,1,9,2,2,5,1,1,9,6,7,4898880
# 16:4,9,1,9,2,2,5,1,1,9,6,7,4,9797760
# 17:9,1,9,2,2,5,1,1,9,6,7,4,4,9797760
# 18:1,9,2,2,5,1,1,9,6,7,4,4,2,2177280
# 19:9,2,2,5,1,1,9,6,7,4,4,2,6,13063680
# 20:2,2,5,1,1,9,6,7,4,4,2,6,5,7257600
# 21:2,5,1,1,9,6,7,4,4,2,6,5,7,25401600
# 22:5,1,1,9,6,7,4,4,2,6,5,7,4,50803200
# 23:1,1,9,6,7,4,4,2,6,5,7,4,7,71124480
# 24:1,9,6,7,4,4,2,6,5,7,4,7,4,284497920
# 25:9,6,7,4,4,2,6,5,7,4,7,4,2,568995840
# 26:6,7,4,4,2,6,5,7,4,7,4,2,3,189665280
# ...

# %%
#13자리 곱 계산
with open("q008_data.txt") as file_object:
    lines = file_object.readlines()

string=''
for line in lines:
    string=string+line.rstrip()

max_value = 0
i=0
loop = len(string)-13
while i < loop:
    product =1
    for j in string[i:i+13]:
        product = product * int(j)
    if product > max_value:
        max_value = product
        print("loop:",i,"max:",product)
    i+=1
print(max_value)
# Out:
# loop: 0 max: 5000940
# loop: 16 max: 9797760
# loop: 19 max: 13063680
# loop: 21 max: 25401600
# loop: 22 max: 50803200
# loop: 23 max: 71124480
# loop: 24 max: 284497920
# loop: 25 max: 568995840
# loop: 40 max: 1020366720
# loop: 41 max: 1632586752
# loop: 43 max: 2040733440
# loop: 88 max: 2972712960
# loop: 195 max: 6270566400
# loop: 196 max: 14108774400
# loop: 197 max: 23514624000
# 23514624000
# calculation time: 0.03699302673339844

# %%
#forum-1
import time

s = time.clock()

x, y, z = '...', [], []

def f( list ):
    o = 1
    for l in list:
        o *= l
    return( o )

for i in range( 1000 ):
    y.append( int( x[ i ] ) )
    if len( y ) >= 13 and f( y[ i - 12 :] ) > 0:
        z.append( f( y[ i - 12 :] ) )

print( max( z ) )
print( time.clock() - s)

# %%
#forum-2
# writing numbers string without line break it is not need use filter(str.isnumeric, ...)
numbers = list(map(int, filter(str.isnumeric,\
"""
73167176531330624919225119674426574742355349194934
96983520312774506326239578318016984801869478851843
85861560789112949495459501737958331952853208805511
12540698747158523863050715693290963295227443043557
66896648950445244523161731856403098711121722383113
62229893423380308135336276614282806444486645238749
30358907296290491560440772390713810515859307960866
70172427121883998797908792274921901699720888093776
65727333001053367881220235421809751254540594752243
52584907711670556013604839586446706324415722155397
53697817977846174064955149290862569321978468622482
83972241375657056057490261407972968652414535100474
82166370484403199890008895243450658541227588666881
16427171479924442928230863465674813919123162824586
17866458359124566529476545682848912883142607690042
24219022671055626321111109370544217506941658960408
07198403850962455444362981230987879927244284909188
84580156166097919133875499200524063689912560717606
05886116467109405077541002256983155200055935729725
71636269561882670428252483600823257530420752963450
""")))

def advance(k0: int):
  try:
    k1 = numbers.index(0, k0 + 1)
    while k1 - k0 <= 13:
      k0 = k1
      k1 = numbers.index(0, k0 + 1)
  except ValueError: pass
  return (k0 + 14), ft.reduce(op.mul, numbers[(k0+1):(k0+14)])

k, x = advance(-1)
S = x
try:
  while True:
    k, x = advance(k) if numbers[k] == 0 else ((k+1), (numbers[k]*x/numbers[k-13]))
    S = max(S, x)
except (IndexError, TypeError, ValueError): pass
print(S)

# %%
#forum-3
import os
import sys

#(10 - 3) + 1

num = ...

def get_digits(total_digits, num_list, start_index):
    dig_list = list()
    for i in range(start_index, start_index + total_digits):
        dig_list.append(num_list[i])

    return dig_list

def calc_product(num_list):
    product = 1
    for i in range(len(num_list)):
        product *= num_list[i]

    return product

num_list = [int(i) for i in str(num)]
digit_break = 13
max_comb = (len(num_list) - digit_break) + 1

max_product = 0

for i in range(max_comb):
    new_prod = calc_product(get_digits(digit_break, num_list, i))
    if new_prod > max_product:
        max_product = new_prod

print(max_product)

# %%
#forum-4
#Find the thirteen adjacent digits in the 1000-digit number that 
#have the greatest product. What is the value of this product?

num = """73167176531330624919225119674426574742355349194934\
96983520312774506326239578318016984801869478851843\
85861560789112949495459501737958331952853208805511\
12540698747158523863050715693290963295227443043557\
66896648950445244523161731856403098711121722383113\
62229893423380308135336276614282806444486645238749\
30358907296290491560440772390713810515859307960866\
70172427121883998797908792274921901699720888093776\
65727333001053367881220235421809751254540594752243\
52584907711670556013604839586446706324415722155397\
53697817977846174064955149290862569321978468622482\
83972241375657056057490261407972968652414535100474\
82166370484403199890008895243450658541227588666881\
16427171479924442928230863465674813919123162824586\
17866458359124566529476545682848912883142607690042\
24219022671055626321111109370544217506941658960408\
07198403850962455444362981230987879927244284909188\
84580156166097919133875499200524063689912560717606\
05886116467109405077541002256983155200055935729725\
71636269561882670428252483600823257530420752963450"""

# Amount of adjacent digits
adj = 13

# Return product of digits from 'index' to 'index + adj - 1'
def getProduct(index):
	prod = 1
	for i in range(index, index + adj, 1):
		prod *= int(num[i])
	return prod

# Returns index of 'zero' if present in range of 
# digit from 'index' to 'index + adj - 1'
# Or returns -1 if 'zero'
def haveZero(index):
	for i in range(index + adj - 1, index - 1, -1):
		if int(num[i]) == 0:
			return i
	return -1

max = 0
i = 0
while i < len(num) - adj + 1:
	isZero = haveZero(i)
	if isZero >= 0:
		i = isZero + 1
		continue
	prod = getProduct(i)
	if max < prod:
		max = prod
	i += 1
print(max)

# %%
#forum-5
'...'
adjecent_digits = 13

maximum_result = 0
for n in range(len(number) - adjecent_digits + 1):
    current_result = 1
    for m in range(adjecent_digits):
        current_result *= int(number[n+m])
    if current_result > maximum_result:
        maximum_result = current_result

print(maximum_result)

# %%
#forum-6

def prod(num):
    total = 1
    for n in str(num):
        total *= int(n)
    return total

number = 73167176531330....62491922511967442
products = []
xpos = 0

while xpos < len(str(number)) - 12:
    products.append(prod(int(str(number)[xpos:xpos+13])))
    xpos += 1

print max(products)
