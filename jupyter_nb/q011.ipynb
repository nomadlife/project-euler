# %% [markdown]
# # Largest product in a grid
#
# In the 20×20 grid below, four numbers along a diagonal line have been marked in red.
#
#
# 08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08<br>
# 49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00<br>
# 81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65<br>
# 52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91<br>
# 22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80<br>
# 24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50<br>
# 32 98 81 28 64 23 67 10 ***`26`*** 38 40 67 59 54 70 66 18 38 64 70<br>
# 67 26 20 68 02 62 12 20 95 ***`63`*** 94 39 63 08 40 91 66 49 94 21<br>
# 24 55 58 05 66 73 99 26 97 17 ***`78`*** 78 96 83 14 88 34 89 63 72<br>
# 21 36 23 09 75 00 76 44 20 45 35 ***`14`*** 00 61 33 97 34 31 33 95<br>
# 78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92<br>
# 16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57<br>
# 86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58<br>
# 19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40<br>
# 04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66<br>
# 88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69<br>
# 04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36<br>
# 20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16<br>
# 20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54<br>
# 01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48
#
#
# The product of these numbers is 26 × 63 × 78 × 14 = 1788696.
#
# What is the greatest product of four adjacent numbers in the same direction (up, down, left, right, or diagonally) in the 20×20 grid?

# %%
# data file download
from urllib.request import urlretrieve
urlretrieve("https://raw.githubusercontent.com/nomadlife/project-euler/master/q011_data.txt", "q011_data.txt")

# %%
# open file
filename = 'q011_data.txt'
with open(filename) as file_object:
	lines = file_object.readlines()
print(lines)
# Out:
# ['08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08\n', '49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00\n', '81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65\n', '52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91\n', '22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80\n', '24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50\n', '32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70\n', '67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21\n', '24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72\n', '21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95\n', '78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92\n', '16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57\n', '86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58\n', '19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40\n', '04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66\n', '88 36 68 87 57 62 20 
# ...

# %%
#change string to list 
numbers=[]
for line in lines:
    print(line.split())
    numbers.append(line.split())
#print(numbers)
# Out:
# ['08', '02', '22', '97', '38', '15', '00', '40', '00', '75', '04', '05', '07', '78', '52', '12', '50', '77', '91', '08']
# ['49', '49', '99', '40', '17', '81', '18', '57', '60', '87', '17', '40', '98', '43', '69', '48', '04', '56', '62', '00']
# ['81', '49', '31', '73', '55', '79', '14', '29', '93', '71', '40', '67', '53', '88', '30', '03', '49', '13', '36', '65']
# ['52', '70', '95', '23', '04', '60', '11', '42', '69', '24', '68', '56', '01', '32', '56', '71', '37', '02', '36', '91']
# ['22', '31', '16', '71', '51', '67', '63', '89', '41', '92', '36', '54', '22', '40', '40', '28', '66', '33', '13', '80']
# ['24', '47', '32', '60', '99', '03', '45', '02', '44', '75', '33', '53', '78', '36', '84', '20', '35', '17', '12', '50']
# ['32', '98', '81', '28', '64', '23', '67', '10', '26', '38', '40', '67', '59', '54', '70', '66', '18', '38', '64', '70']
# ['67', '26', '20', '68', '02', '62', '12', '20', '95', '63', '94', '39', '63', '08', '40', '91', '66', '49', '94', '21']
# ...

# %%
#access list
for i in range(20):
    for j in range(20):
        print(i,j,numbers[i][j])
# Out:
# 0 0 08
# 0 1 02
# 0 2 22
# 0 3 97
# 0 4 38
# 0 5 15
# 0 6 00
# 0 7 40
# 0 8 00
# 0 9 75
# 0 10 04
# 0 11 05
# 0 12 07
# 0 13 78
# 0 14 52
# 0 15 12
# 0 16 50
# 0 17 77
# 0 18 91
# 0 19 08
# 1 0 49
# 1 1 49
# 1 2 99
# 1 3 40
# 1 4 17
# 1 5 81
# 1 6 18
# 1 7 57
# 1 8 60
# 1 9 87
# 1 10 17
# 1 11 40
# 1 12 98
# 1 13 43
# 1 14 69
# 1 15 48
# 1 16 04
# 1 17 56
# 1 18 62
# 1 19 00
# 2 0 81
# 2 1 49
# 2 2 31
# 2 3 73
# 2 4 55
# 2 5 79
# 2 6 14
# 2 7 29
# 2 8 93
# 2 9 71
# 2 10 40
# 2 11 67
# 2 12 53
# 2 13 88
# 2 14 30
# 2 15 03
# 2 16 49
# 2 17 13
# 2 18 36
# 2 19 65
# 3 0 52
# 3 1 70
# 3 2 95
# 3 3 23
# 3 4 04
# 3 5 60
# 3 6 11
# 3 7 42
# 3 8 69
# 3 9 24
# 3 10 68
# 3 11 56
# 3 12 01
# 3 13 32
# 3 14 56
# 3 15 71
# 3 16 37
# 3 17 02
# 3 18 36
# 3 19 91
# 4 0 22
# 4 1 31
# 4 2 16
# 4 3 71
# 4 4 51
# 4 5 67
# 4 6 63
# 4 7 89
# 4 8 41
# 4 9 92
# 4 10 36
# 4 11 54
# 4 12 22
# 4 13 40
# 4 14 40
# 4 15 28
# 4 16 66
# 4 17 33
# 4 18 13
# 4 19 80
# 5 0 24
# 5 1 47
# 5 2 32
# 5 3 60
# 5 4 99
# ...

# %%
# 1. make sub array
from functools import reduce
for i in range(17):
    for j in range(17):
        subList = []
        for k in range(4):
            for l in range(4):
                subList.append(numbers[i+k][j+l])
        print(subList)
        prodH = [reduce(lambda x, y: x+y, subList[0+i:4+i]) for i in range(0,16,4)]
        prodV = [reduce(lambda x, y: x+y, subList[i:16:4]) for i in range(0,4)]
        prodD1 = reduce(lambda x, y: x+y, subList[0:16:5])
        prodD2 = reduce(lambda x, y: x+y, subList[3:15:3])
        print("prodH:",prodH)
        print("prodV:",prodV)
        print("prodD1:",prodD1)
        print("prodD2:",prodD2)
# Out:
# ['08', '02', '22', '97', '49', '49', '99', '40', '81', '49', '31', '73', '52', '70', '95', '23']
# prodH: ['08022297', '49499940', '81493173', '52709523']
# prodV: ['08498152', '02494970', '22993195', '97407323']
# prodD1: ['08493123']
# prodD2: ['97994952']
# ['02', '22', '97', '38', '49', '99', '40', '17', '49', '31', '73', '55', '70', '95', '23', '04']
# prodH: ['02229738', '49994017', '49317355', '70952304']
# prodV: ['02494970', '22993195', '97407323', '38175504']
# prodD1: ['02997304']
# prodD2: ['38403170']
# ['22', '97', '38', '15', '99', '40', '17', '81', '31', '73', '55', '79', '95', '23', '04', '60']
# prodH: ['22973815', '99401781', '31735579', '95230460']
# prodV: ['22993195', '97407323', '38175504', '15817960']
# prodD1: ['22405560']
# prodD2: ['15177395']
# ['97', '38', '15', '00', '40', '17', '81', '18', '73', '55', '79', '14', '23', '04', '60', '11']
# prodH: ['97381500', '40178118', '73557914', '23046011']
# prodV: ['97407323', '38175504', '15817960', '00181411']
# ...

# %%
# 2. test - without subarray
from functools import reduce

prodH = reduce(lambda x, y: x+y, numbers[0][0:4])
print("prodH:",prodH)
# Out:
# prodH: 08022297

# %%
# 2. test(2) - without subarray
from functools import reduce

for i in range(17):
    for j in range(17):
        prodH = reduce(lambda x, y: x+y, numbers[i][j:j+4])
        print("prodH:",prodH)
# Out:
# prodH: 08022297
# prodH: 02229738
# prodH: 22973815
# prodH: 97381500
# prodH: 38150040
# prodH: 15004000
# prodH: 00400075
# prodH: 40007504
# prodH: 00750405
# prodH: 75040507
# prodH: 04050778
# prodH: 05077852
# prodH: 07785212
# prodH: 78521250
# prodH: 52125077
# prodH: 12507791
# prodH: 50779108
# prodH: 49499940
# prodH: 49994017
# prodH: 99401781
# prodH: 40178118
# prodH: 17811857
# prodH: 81185760
# prodH: 18576087
# prodH: 57608717
# prodH: 60871740
# prodH: 87174098
# prodH: 17409843
# prodH: 40984369
# prodH: 98436948
# prodH: 43694804
# prodH: 69480456
# prodH: 48045662
# prodH: 04566200
# prodH: 81493173
# prodH: 49317355
# prodH: 31735579
# prodH: 73557914
# prodH: 55791429
# prodH: 79142993
# prodH: 14299371
# prodH: 29937140
# prodH: 93714067
# prodH: 71406753
# prodH: 40675388
# prodH: 67538830
# prodH: 53883003
# prodH: 88300349
# prodH: 30034913
# prodH: 03491336
# prodH: 49133665
# prodH: 52709523
# prodH: 70952304
# prodH: 95230460
# prodH: 23046011
# ...

# %%
# 2. test(3) - without subarray
from functools import reduce


prodV = reduce(lambda x, y: x+y, [numbers[0+k][0] for k in range(0,4)])
print("prodV:",prodV)
# Out:
# prodV: 08498152

# %%
# 2. without subarray
from functools import reduce

for i in range(17):
    for j in range(17):
        prodH = reduce(lambda x, y: x+y, numbers[i][j:j+4])
        prodV = reduce(lambda x, y: x+y, [numbers[i+k][j] for k in range(0,4)])
        print("prodH:",prodH)
        print("prodV:",prodV)
# Out:
# prodH: 08022297
# prodV: 08498152
# prodH: 02229738
# prodV: 02494970
# prodH: 22973815
# prodV: 22993195
# prodH: 97381500
# prodV: 97407323
# prodH: 38150040
# prodV: 38175504
# prodH: 15004000
# prodV: 15817960
# prodH: 00400075
# prodV: 00181411
# prodH: 40007504
# prodV: 40572942
# prodH: 00750405
# prodV: 00609369
# prodH: 75040507
# prodV: 75877124
# prodH: 04050778
# prodV: 04174068
# prodH: 05077852
# prodV: 05406756
# prodH: 07785212
# prodV: 07985301
# prodH: 78521250
# prodV: 78438832
# prodH: 52125077
# prodV: 52693056
# prodH: 12507791
# prodV: 12480371
# prodH: 50779108
# prodV: 50044937
# prodH: 49499940
# prodV: 49815222
# prodH: 49994017
# prodV: 49497031
# prodH: 99401781
# prodV: 99319516
# prodH: 40178118
# prodV: 40732371
# prodH: 17811857
# prodV: 17550451
# prodH: 81185760
# prodV: 81796067
# prodH: 18576087
# prodV: 18141163
# prodH: 57608717
# prodV: 57294289
# prodH: 60871740
# prodV: 60936941
# prodH: 87174098
# prodV: 87712492
# prodH: 17409843
# ...

# %%
# 2. without subarray
from functools import reduce

for i in range(17):
    for j in range(17):
        prodH = reduce(lambda x, y: x+y, numbers[i][j:j+4])
        prodV = reduce(lambda x, y: x+y, [numbers[i+k][j] for k in range(0,4)])
        prodD1 = reduce(lambda x, y: x+y, [numbers[i+k][j+k] for k in range(0,4)])
        prodD2 = reduce(lambda x, y: x+y, [numbers[i+k][j+3-k] for k in range(0,4)])
        print("prodH:",prodH)
        print("prodV:",prodV)
        print("prodD1:",prodD1)
        print("prodD2:",prodD2)
# Out:
# prodH: 08022297
# prodV: 08498152
# prodD1: 08493123
# prodD2: 97994952
# prodH: 02229738
# prodV: 02494970
# prodD1: 02997304
# prodD2: 38403170
# prodH: 22973815
# prodV: 22993195
# prodD1: 22405560
# prodD2: 15177395
# prodH: 97381500
# prodV: 97407323
# prodD1: 97177911
# prodD2: 00815523
# prodH: 38150040
# prodV: 38175504
# prodD1: 38811442
# prodD2: 40187904
# prodH: 15004000
# prodV: 15817960
# prodD1: 15182969
# prodD2: 00571460
# prodH: 00400075
# prodV: 00181411
# prodD1: 00579324
# prodD2: 75602911
# prodH: 40007504
# prodV: 40572942
# prodD1: 40607168
# prodD2: 04879342
# prodH: 00750405
# prodV: 00609369
# prodD1: 00874056
# prodD2: 05177169
# prodH: 75040507
# prodV: 75877124
# prodD1: 75176701
# prodD2: 07404024
# prodH: 04050778
# prodV: 04174068
# prodD1: 04405332
# prodD2: 78986768
# prodH: 05077852
# prodV: 05406756
# prodD1: 05988856
# prodD2: 52435356
# prodH: 07785212
# prodV: 07985301
# prodD1: 07433071
# prodD2: 12698801
# prodH: 78521250
# prodV: 78438832
# ...

# %%
# 2-2 save to array
from functools import reduce

for i in range(17):
    for j in range(17):
        prod=[]
        prod.append(reduce(lambda x, y: x+y, numbers[i][j:j+4]))
        prod.append(reduce(lambda x, y: x+y, [numbers[i+k][j] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: x+y, [numbers[i+k][j+k] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: x+y, [numbers[i+k][j+3-k] for k in range(0,4)]))
        print("prod:",prod)
# Out:
# prod: ['08022297', '08498152', '08493123', '97994952']
# prod: ['02229738', '02494970', '02997304', '38403170']
# prod: ['22973815', '22993195', '22405560', '15177395']
# prod: ['97381500', '97407323', '97177911', '00815523']
# prod: ['38150040', '38175504', '38811442', '40187904']
# prod: ['15004000', '15817960', '15182969', '00571460']
# prod: ['00400075', '00181411', '00579324', '75602911']
# prod: ['40007504', '40572942', '40607168', '04879342']
# prod: ['00750405', '00609369', '00874056', '05177169']
# prod: ['75040507', '75877124', '75176701', '07404024']
# prod: ['04050778', '04174068', '04405332', '78986768']
# prod: ['05077852', '05406756', '05988856', '52435356']
# prod: ['07785212', '07985301', '07433071', '12698801']
# prod: ['78521250', '78438832', '78690337', '50483032']
# prod: ['52125077', '52693056', '52484902', '77040356']
# prod: ['12507791', '12480371', '12041336', '91564971']
# prod: ['50779108', '50044937', '50563691', '08621337']
# ...

# %%
# 2-3 calculation
from functools import reduce

for i in range(17):
    for j in range(17):
        prod=[]
        prod.append(reduce(lambda x, y: int(x)*int(y), numbers[i][j:j+4]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j+k] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j+3-k] for k in range(0,4)]))
        print("prod:",prod)
# Out:
# prod: [34144, 1651104, 279496, 24468444]
# prod: [162184, 336140, 57816, 3298400]
# prod: [1216380, 6414210, 2904000, 1768425]
# prod: [0, 6514520, 1432981, 0]
# prod: [0, 142120, 1809864, 227520]
# prod: [0, 5759100, 540270, 0]
# prod: [0, 0, 0, 1435500]
# prod: [0, 2777040, 11587200, 1359288]
# prod: [0, 0, 0, 416415]
# prod: [10500, 11118600, 85425, 268800]
# prod: [10920, 184960, 271360, 34826064]
# prod: [141960, 750400, 2414720, 6636448]
# prod: [340704, 36358, 641130, 72864]
# prod: [2433600, 9444864, 597402, 2304000]
# prod: [2402400, 6027840, 244608, 51744]
# prod: [4204200, 122688, 22464, 17728984]
# prod: [2802800, 362600, 9172800, 238576]
# prod: [9507960, 4540536, 16194745, 1909600]
# prod: [3298680, 5210170, 1781787, 3654745]
# prod: [5452920, 4664880, 1936836, 1639440]
# prod: [991440, 4768360, 8316000, 403848]
# prod: [1412802, 190740, 1314797, 2441880]
# prod: [4986360, 25723980, 1952748, 1282380]
# prod: [5355720, 174636, 3313656, 21408786]
# ...

# %%
# 2-4 calc maxValue
from functools import reduce

maxValue=0
for i in range(17):
    for j in range(17):
        prod=[]
        prod.append(reduce(lambda x, y: int(x)*int(y), numbers[i][j:j+4]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j+k] for k in range(0,4)]))
        prod.append(reduce(lambda x, y: int(x)*int(y), [numbers[i+k][j+3-k] for k in range(0,4)]))
        if max(prod) > maxValue:
            maxValue = max(prod)
print(maxValue)
# Out:
# 70600674

# %% [markdown]
# solution end

# %%
#previous solution

max_product=0
for i in range(20):
    for j in range(20):
        
        #가로숫자 4개 곱
        if j+4 < 20:
            product =1
            print(i,j,end=':')
            for k in range(0,4):
                print(numbers[i][j+k],end='*')
                product *= int(numbers[i][j+k])
            print("=",product,end=' ')
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
            print()

print("max_product is ",max_product)
# Out:
# 0 0:08*02*22*97*= 34144 max_product : 34144
#
# 0 1:02*22*97*38*= 162184 max_product : 162184
#
# 0 2:22*97*38*15*= 1216380 max_product : 1216380
#
# 0 3:97*38*15*00*= 0
# 0 4:38*15*00*40*= 0
# 0 5:15*00*40*00*= 0
# 0 6:00*40*00*75*= 0
# 0 7:40*00*75*04*= 0
# 0 8:00*75*04*05*= 0
# 0 9:75*04*05*07*= 10500
# 0 10:04*05*07*78*= 10920
# 0 11:05*07*78*52*= 141960
# 0 12:07*78*52*12*= 340704
# 0 13:78*52*12*50*= 2433600 max_product : 2433600
#
# 0 14:52*12*50*77*= 2402400
# 0 15:12*50*77*91*= 4204200 max_product : 4204200
#
# 1 0:49*49*99*40*= 9507960 max_product : 9507960
#
# 1 1:49*99*40*17*= 3298680
# 1 2:99*40*17*81*= 5452920
# 1 3:40*17*81*18*= 991440
# 1 4:17*81*18*57*= 1412802
# 1 5:81*18*57*60*= 4986360
# 1 6:18*57*60*87*= 5355720
# 1 7:57*60*87*17*= 5058180
# 1 8:60*87*17*40*= 3549600
# 1 9:87*17*40*98*= 5797680
# 1 10:17*40*98*43*= 2865520
# 1 11:40*98*43*69*= 11630640 max_product : 11630640
#
# 1 12:98*43*69*48*= 13956768 max_product : 13956768
#
# 1 13:43*69*48*04*= 569664
# ...

# %%
max_product=0
for i in range(20):
    for j in range(20):
        
        #가로숫자 4개 곱
        if j+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i][j+k])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
        
        #세로숫자 4개 곱
        if i+4 < 20:
            product =1
            print(i,j,end=':')
            for k in range(0,4):
                print(numbers[i+k][j],end='*')
                product *= int(numbers[i+k][j])
            print("=",product,end=' ')
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
            print()        

print("max_product is ",max_product)
# Out:
# max_product : 34144
# 0 0:08*49*81*52*= 1651104 max_product : 1651104
#
# 0 1:02*49*49*70*= 336140
# 0 2:22*99*31*95*= 6414210 max_product : 6414210
#
# 0 3:97*40*73*23*= 6514520 max_product : 6514520
#
# 0 4:38*17*55*04*= 142120
# 0 5:15*81*79*60*= 5759100
# 0 6:00*18*14*11*= 0
# 0 7:40*57*29*42*= 2777040
# 0 8:00*60*93*69*= 0
# 0 9:75*87*71*24*= 11118600 max_product : 11118600
#
# 0 10:04*17*40*68*= 184960
# 0 11:05*40*67*56*= 750400
# 0 12:07*98*53*01*= 36358
# 0 13:78*43*88*32*= 9444864
# 0 14:52*69*30*56*= 6027840
# 0 15:12*48*03*71*= 122688
# 0 16:50*04*49*37*= 362600
# 0 17:77*56*13*02*= 112112
# 0 18:91*62*36*36*= 7312032
# 0 19:08*00*65*91*= 0
# 1 0:49*81*52*22*= 4540536
# 1 1:49*49*70*31*= 5210170
# 1 2:99*31*95*16*= 4664880
# 1 3:40*73*23*71*= 4768360
# 1 4:17*55*04*51*= 190740
# 1 5:81*79*60*67*= 25723980 max_product : 25723980
#
# 1 6:18*14*11*63*= 174636
# 1 7:57*29*42*89*= 6178914
# 1 8:60*93*69*41*= 15785820
# 1 9:87*71*24*92*= 13638816
# 1 10:17*40*68*36*= 1664640
# ...

# %%
max_product=0
for i in range(20):
    for j in range(20):

        #가로숫자 4개 곱
        if j+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i][j+k])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)

        #세로숫자 4개 곱
        if i+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i+k][j])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)

        #대각선(↘)숫자 4개 곱
        if i+4 < 20 and j+4 < 20:
            product =1
            print(i,j,end=':')
            for k in range(0,4):
                print(numbers[i+k][j+k],end='*')
                product *= int(numbers[i+k][j+k])
            print("=",product,end=' ')
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
            print()
            
print("max_product is ",max_product)
# Out:
# max_product : 34144
# max_product : 1651104
# 0 0:08*49*31*23*= 279496
# 0 1:02*99*73*04*= 57816
# max_product : 6414210
# 0 2:22*40*55*60*= 2904000
# max_product : 6514520
# 0 3:97*17*79*11*= 1432981
# 0 4:38*81*14*42*= 1809864
# 0 5:15*18*29*69*= 540270
# 0 6:00*57*93*24*= 0
# 0 7:40*60*71*68*= 11587200 max_product : 11587200
#
# 0 8:00*87*40*56*= 0
# 0 9:75*17*67*01*= 85425
# 0 10:04*40*53*32*= 271360
# 0 11:05*98*88*56*= 2414720
# 0 12:07*43*30*71*= 641130
# 0 13:78*69*03*37*= 597402
# 0 14:52*48*49*02*= 244608
# 0 15:12*04*13*36*= 22464
# 1 0:49*49*95*71*= 16194745 max_product : 16194745
#
# 1 1:49*31*23*51*= 1781787
# 1 2:99*73*04*67*= 1936836
# 1 3:40*55*60*63*= 8316000
# 1 4:17*79*11*89*= 1314797
# max_product : 25723980
# 1 5:81*14*42*41*= 1952748
# 1 6:18*29*69*92*= 3313656
# 1 7:57*93*24*36*= 4580064
# 1 8:60*71*68*54*= 15642720
# 1 9:87*40*56*22*= 4287360
# 1 10:17*67*01*40*= 45560
# 1 11:40*53*32*40*= 2713600
# 1 12:98*88*56*28*= 13522432
# 1 13:43*30*71*66*= 6044940
# ...

# %%
max_product=0
for i in range(20):
    for j in range(20):
        
        #가로숫자 4개 곱
        if j+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i][j+k])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)

        #세로숫자 4개 곱
        if i+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i+k][j])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
        
        #대각선(↘)숫자 4개 곱
        if i+4 < 20 and j+4 < 20:
            product =1
            for k in range(0,4):
                product *= int(numbers[i+k][j+k])
            if product >max_product:
                max_product = product
                print("max_product :",max_product)

        #대각선(↙)숫자 4개 곱
        if i+4 < 20 and j+4 < 20 and j >= 3:
            product =1
            print(i,j,end=':')
            for k in range(0,4):
                print(numbers[i+k][j-k],end='*')
                product *= int(numbers[i+k][j-k])
            print("=",product,end=' ')
            if product >max_product:
                max_product = product
                print("max_product :",max_product)
            print()
            
print("max_product is ",max_product)
# Out:
# max_product : 34144
# max_product : 1651104
# max_product : 6414210
# max_product : 6514520
# 0 3:97*99*49*52*= 24468444 max_product : 24468444
#
# 0 4:38*40*31*70*= 3298400
# 0 5:15*17*73*95*= 1768425
# 0 6:00*81*55*23*= 0
# 0 7:40*18*79*04*= 227520
# 0 8:00*57*14*60*= 0
# 0 9:75*60*29*11*= 1435500
# 0 10:04*87*93*42*= 1359288
# 0 11:05*17*71*69*= 416415
# 0 12:07*40*40*24*= 268800
# 0 13:78*98*67*68*= 34826064 max_product : 34826064
#
# 0 14:52*43*53*56*= 6636448
# 0 15:12*69*88*01*= 72864
# 1 3:40*31*70*22*= 1909600
# 1 4:17*73*95*31*= 3654745
# 1 5:81*55*23*16*= 1639440
# 1 6:18*79*04*71*= 403848
# 1 7:57*14*60*51*= 2441880
# 1 8:60*29*11*67*= 1282380
# 1 9:87*93*42*63*= 21408786
# 1 10:17*71*69*89*= 7412187
# 1 11:40*40*24*41*= 1574400
# 1 12:98*67*68*92*= 41076896 max_product : 41076896
#
# 1 13:43*53*56*36*= 4594464
# 1 14:69*88*01*54*= 327888
# 1 15:48*30*32*22*= 1013760
# 2 3:73*95*31*24*= 5159640
# 2 4:55*23*16*47*= 951280
# 2 5:79*04*71*32*= 717952
# ...

# %%
max_product=0
for i in range(20):
    for j in range(20):
        
        #가로숫자 4개 곱
        product =1
        if j+4 < 20:
            for k in range(0,4):
                product *= int(numbers[i][j+k])
            if product >max_product:
                max_product = product

        #세로숫자 4개 곱
        product =1
        if i+4 < 20:
            for k in range(0,4):
                product *= int(numbers[i+k][j])
            if product >max_product:
                max_product = product
        
        #대각선(↘)숫자 4개 곱
        product =1
        if i+4 < 20 and j+4 < 20:
            for k in range(0,4):
                product *= int(numbers[i+k][j+k])
            if product >max_product:
                max_product = product
        
        #대각선(↙)숫자 4개 곱
        product =1
        if i+4 < 20 and j+4 < 20 and j >= 3:
            for k in range(0,4):
                product *= int(numbers[i+k][j-k])
            if product >max_product:
                max_product = product

            
print("max_product is ",max_product)
# Out:
# max_product is  70600674

# %%
#forum-1
str = """08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08
49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00
81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65
52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91
22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80
24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50
32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70
67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21
24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72
21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95
78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92
16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57
86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58
19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40
04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66
88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69
04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36
20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16
20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54
01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48"""


def convert_to_matrix(st):
    mat = st.splitlines()
    for a, b in enumerate(mat):
        mat[a] = mat[a].split(' ')

    for a, b in enumerate(mat):
        for i,j in enumerate(mat[a]):
            mat[a][i] = int(mat[a][i])

    return mat


def product_adjacent_numbers(mat, adjacent_numbers):
    len_m = len(mat)
    max_prod = 0
    for i in range(len_m):
        for j in range(len_m-adjacent_numbers):
            # Hacia la derecha del número
            prod = mat[i][j] * mat[i][j + 1] * mat[i][j + 2] * mat[i][j + 3]
            if prod > max_prod:
                max_prod = prod
            # Hacia la izquierda del número
            prod = mat[j][i] * mat[j + 1][i] * mat[j + 2][i] * mat[j + 3][i]
            if prod > max_prod:
                max_prod = prod

    # Diegonal derecha inferior
    for i in range(len_m-adjacent_numbers):
        for j in range(len_m-adjacent_numbers):
            prod = mat[i][j] * mat[i + 1][j + 1] * mat[i + 2][j + 2] * mat[i + 3][j + 3]
            if prod > max_prod:
                max_prod = prod
    # Diagonal izquierda inferior
    for i in range(adjacent_numbers-1, len_m):
        for j in range(len_m-adjacent_numbers):
            prod = mat[i][j] * mat[i - 1][j + 1] * mat[i - 2][j + 2] * mat[i - 3][j + 3]
            if prod > max_prod:
                max_prod = prod

    return max_prod


mat = convert_to_matrix(str)

adjacent_numbers = 4

n = product_adjacent_numbers(mat, adjacent_numbers)

print(n)

# %%
#forum-2
import numpy as np

k = 4
a = np.array([[int(x) for x in l.split()] for l in open('euler11.txt')])
starts = np.ndindex(a.shape)
dirs = np.array([[0, 1], [1, 0], [-1, 1], [1, 1]])
segment_idx = [np.array([start + dir * i for i in range(k)]) for start in starts for dir in dirs]
segments = np.array([a[tuple(idx.T)] for idx in segment_idx if (idx < np.array(a.shape)).all()])
answer = segments.prod(axis=1).max()

print(answer)

# %%
#forum-3
# Array was converted with "Find and Replace". Too lazy to write str to int[][] convertion
num = [["08", "02", "22", "97", "38", "15", "00", "40", "00", "75", "04", "05", "07", "78", "52", "12", "50", "77", "91", "08"],
["49", "49", "99", "40", "17", "81", "18", "57", "60", "87", "17", "40", "98", "43", "69", "48", "04", "56", "62", "00"],
["81", "49", "31", "73", "55", "79", "14", "29", "93", "71", "40", "67", "53", "88", "30", "03", "49", "13", "36", "65"],
["52", "70", "95", "23", "04", "60", "11", "42", "69", "24", "68", "56", "01", "32", "56", "71", "37", "02", "36", "91"],
["22", "31", "16", "71", "51", "67", "63", "89", "41", "92", "36", "54", "22", "40", "40", "28", "66", "33", "13", "80"],
["24", "47", "32", "60", "99", "03", "45", "02", "44", "75", "33", "53", "78", "36", "84", "20", "35", "17", "12", "50"],
["32", "98", "81", "28", "64", "23", "67", "10", "26", "38", "40", "67", "59", "54", "70", "66", "18", "38", "64", "70"],
["67", "26", "20", "68", "02", "62", "12", "20", "95", "63", "94", "39", "63", "08", "40", "91", "66", "49", "94", "21"],
["24", "55", "58", "05", "66", "73", "99", "26", "97", "17", "78", "78", "96", "83", "14", "88", "34", "89", "63", "72"],
["21", "36", "23", "09", "75", "00", "76", "44", "20", "45", "35", "14", "00", "61", "33", "97", "34", "31", "33", "95"],
["78", "17", "53", "28", "22", "75", "31", "67", "15", "94", "03", "80", "04", "62", "16", "14", "09", "53", "56", "92"],
["16", "39", "05", "42", "96", "35", "31", "47", "55", "58", "88", "24", "00", "17", "54", "24", "36", "29", "85", "57"],
["86", "56", "00", "48", "35", "71", "89", "07", "05", "44", "44", "37", "44", "60", "21", "58", "51", "54", "17", "58"],
["19", "80", "81", "68", "05", "94", "47", "69", "28", "73", "92", "13", "86", "52", "17", "77", "04", "89", "55", "40"],
["04", "52", "08", "83", "97", "35", "99", "16", "07", "97", "57", "32", "16", "26", "26", "79", "33", "27", "98", "66"],
["88", "36", "68", "87", "57", "62", "20", "72", "03", "46", "33", "67", "46", "55", "12", "32", "63", "93", "53", "69"],
["04", "42", "16", "73", "38", "25", "39", "11", "24", "94", "72", "18", "08", "46", "29", "32", "40", "62", "76", "36"],
["20", "69", "36", "41", "72", "30", "23", "88", "34", "62", "99", "69", "82", "67", "59", "85", "74", "04", "36", "16"],
["20", "73", "35", "29", "78", "31", "90", "01", "74", "31", "49", "71", "48", "86", "81", "16", "23", "57", "05", "54"],
["01", "70", "54", "71", "83", "51", "54", "69", "16", "92", "33", "48", "61", "43", "52", "01", "89", "19", "67", "48"]]

sizeX = len(num[0])
sizeY = len(num)
adj = 4
max = 0

# Returns prod of given direction
def calcByDir(i, j, dir):
	prod = 1
	if dir == "r":
		for k in range(j, j+adj):
			if num[i][k] == "00":
				return 0
			prod *= int(num[i][k])
	elif dir == "d":
		for k in range(i, i+adj):
			if num[k][j] == "00":
				return 0
			prod *= int(num[k][j])
	elif dir == "dr":
		for k in range(0, adj):
			if num[i - k][j + k] == "00":
				return 0
			prod *= int(num[i - k][j + k])
	elif dir == "dl":
		for k in range(0, adj):
			if num[i - k][j - k] == "00":
				return 0
			prod *= int(num[i - k][j - k])
	return prod

# Set 'max' if 'prod' is higher
def setMax(prod):
	global max
	if max < prod:
		max = prod

# main loop
for i in range(0, sizeY - adj + 1):
	for j in range(0, sizeX):
		if j < sizeY - adj + 1:
			prod = calcByDir(i, j, "r")
			setMax(prod)
		if i < sizeX - adj + 1:
			prod = calcByDir(i, j, "d")
			setMax(prod)
			if j > adj - 2:
				prod = calcByDir(i, j, "dl")
				setMax(prod)
			if j < sizeY - adj + 1:
				prod = calcByDir(i, j, "dr")
				setMax(prod)
print(max)

# %%
#forum-4
import itertools

nums=map(lambda x:int(x),"""
08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08 
49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00 
81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65 
52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91 
22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80 
24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50 
32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70 
67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21 
24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72 
21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95 
78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92 
16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57 
86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58 
19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40 
04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66 
88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69 
04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36 
20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16 
20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54 
01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48
""".replace("\n","").split(" "))

print max(map(lambda i: max(map( lambda lm,index=i: reduce((lambda x,y: x*y),lm(index)), [
    lambda x: nums[x: x + 80: 20], #down
    lambda x: nums[x: x- 80 if (x>80) else None: -20], #up
    lambda x: nums[x: x + 4 if (x/20) == (x+4)/20 else ((x/20)+1)*20], #right
    lambda x: nums[x - 3 if (x-3)/20 == x/20 else (x/20)*20: x+1], #left
    lambda x: nums[x: x + (84 if (x%20<17) else 21 * (19-x%20)+1): 21], #downright
    lambda x: nums[x: x + (76 if (x%20>2)  else 19 * (x%20)+1): 19], #downleft
    lambda x: nums[x - ((63 if (x/20 > 2) else x/20*21) if (x%20>=x/20) else (63 if (x%20>2) else x%20*21)): x+1: 21], #upleft
    lambda x: nums[x - ((57 if (x/20 > 2) else x/20*19) if (x/20<=(19-x%20)) else (57 if (x%20<17) else (19-x%20)*19)): x+1: 19] #upright
])), range(len(nums))))

# %%
#forum-5
numGrid = [
[8,2,22,97,38,15,00,40,00,75,4,5,7,78,52,12,50,77,91,8],
[49,49,99,40,17,81,18,57,60,87,17,40,98,43,69,48,4,56,62,0],
[81,49,31,73,55,79,14,29,93,71,40,67,53,88,30,3,49,13,36,65],
[52,70,95,23,4,60,11,42,69,24,68,56,1,32,56,71,37,2,36,91],
[22,31,16,71,51,67,63,89,41,92,36,54,22,40,40,28,66,33,13,80],
[24,47,32,60,99,3,45,2,44,75,33,53,78,36,84,20,35,17,12,50],
[32,98,81,28,64,23,67,10,26,38,40,67,59,54,70,66,18,38,64,70],
[67,26,20,68,2,62,12,20,95,63,94,39,63,8,40,91,66,49,94,21],
[24,55,58,5,66,73,99,26,97,17,78,78,96,83,14,88,34,89,63,72],
[21,36,23,9,75,00,76,44,20,45,35,14,00,61,33,97,34,31,33,95],
[78,17,53,28,22,75,31,67,15,94,3,80,4,62,16,14,9,53,56,92],
[16,39,5,42,96,35,31,47,55,58,88,24,00,17,54,24,36,29,85,57],
[86,56,00,48,35,71,89,7,5,44,44,37,44,60,21,58,51,54,17,58],
[19,80,81,68,5,94,47,69,28,73,92,13,86,52,17,77,4,89,55,40],
[4,52,8,83,97,35,99,16,7,97,57,32,16,26,26,79,33,27,98,66],
[88,36,68,87,57,62,20,72,3,46,33,67,46,55,12,32,63,93,53,69],
[4,42,16,73,38,25,39,11,24,94,72,18,8,46,29,32,40,62,76,36],
[20,69,36,41,72,30,23,88,34,62,99,69,82,67,59,85,74,4,36,16],
[20,73,35,29,78,31,90,1,74,31,49,71,48,86,81,16,23,57,5,54],
[1,70,54,71,83,51,54,69,16,92,33,48,61,43,52,1,89,19,67,48]]


n = 4 # length of each iteration
productList = []
def diagLRProduct():
	d1Product = 1
	largestDiagLRProduct = 0
	for h in range(len(numGrid[0])-(n-1)):		#specifies length of vertical
		for j in range(len(numGrid[0])-(n-1)):	#specifies length of horizontal
			for i in range(n):		#finds four diagonal left to right factors
				d1Product = (d1Product * numGrid[i+h][j])
				j += 1
				if d1Product > largestDiagLRProduct:
					largestDiagLRProduct = d1Product
			#print(d1Product, end = ' ')	
			d1Product = 1
	productList.append(largestDiagLRProduct)

def diagRLProduct():
	d2Product = 1
	largestDiagRLProduct = 0
	for h in range(len(numGrid[0])-(n-1)):		#specifies length of vertical
		for j in range(len(numGrid[0])-(n-1)):	#specifies length of horizontal
			for i in range(n):		#finds four diagonal right to left factors
				d2Product = (d2Product * numGrid[i+h][19-j])
				j += 1
				if d2Product > largestDiagRLProduct:
					largestDiagRLProduct = d2Product	
			d2Product = 1
	productList.append(largestDiagRLProduct)


def horizProduct():
	hProduct = 1
	largestHorizProduct = 0
	for h in range(len(numGrid[0])):		#specifies length of vertical
		for j in range(len(numGrid[0])-(n-1)):	#specifies length of horizontal
			for i in range(n):		#finds four horizontal factors				
				hProduct = (hProduct * numGrid[h][i+j])
				if hProduct > largestHorizProduct:
					largestHorizProduct = hProduct
			hProduct = 1
	productList.append(largestHorizProduct)

def vertProduct():
	vProduct = 1
	largestVertProduct = 0
	for h in range(len(numGrid[0])):		#specifies length of vertical
		for j in range(len(numGrid[0])-(n-1)):	#specifies length of horizontal
			for i in range(n):		#finds four vertical factors					
				vProduct = (vProduct * numGrid[i+j][h])
				if vProduct > largestVertProduct:
					largestVertProduct = vProduct	
			vProduct = 1
	productList.append(largestVertProduct)

diagLRProduct()
diagRLProduct()
horizProduct()
vertProduct()
print(max(productList))

# %%
#forum-6
lX = '08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08 49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00 81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65 52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91 22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80 24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50 32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70 67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21 24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72 21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95 78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92 16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57 86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58 19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40 04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66 88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69 04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36 20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16 20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54 01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48'.split()
lY = []
lA = []

for iX in lX:
    lA.append( int( iX ) )

for iY in range( 0, 400, 20 ):
    lY.append( lA[ iY : ( iY + 20 ) ] )

lX = []
lZ = []
lV = []
lW = []

for i1 in range( 17 ):
    for i2 in range( 17 ):
        #\
        lX.append( ( lY[ i1 ][ i2 ] ) * ( lY[ i1 + 1 ][ i2 + 1 ] ) * ( lY[ i1 + 2 ][ i2 + 2 ] ) * ( lY[ i1 + 3 ][ i2 + 3 ] ) )
        #__
        lZ.append( ( lY[ i1 ][ i2 ] ) * ( lY[ i1 ][ i2 + 1 ] ) * ( lY[ i1 ][ i2 + 2 ] ) * ( lY[ i1 ][ i2 + 3 ] ) )
    for i3 in range( 20 ):
        #|
        lV.append( ( lY[ i1 ][ i3 ] ) * ( lY[ i1 + 1 ][ i3 ] ) * ( lY[ i1 + 2 ][ i3 ] ) * ( lY[ i1 + 3 ][ i3 ] ) )
    for i4 in range( 3, 20 ):
        #/
        lW.append( ( lY[ i1 ][ i4 ] ) * ( lY[ i1 + 1 ][ i4 - 1 ] ) * ( lY[ i1 + 2 ][ i4 - 2 ] ) * ( lY[ i1 + 3 ][ i4 - 3 ] ) )

for i5 in range( 17, 20 ):
    for ic in range( 17 ):
        #__
        lZ.append( ( lY[ i5 ][ ic ] ) * ( lY[ i5 ][ ic + 1 ] ) * ( lY[ i5 ][ ic + 2 ] ) * ( lY[ i5 ][ ic + 3 ] ) )

print( max( max( lX ), max( lZ ), max( lV ), max( lW ) ) )
