# %% [markdown]
# # Q034 Digit factorials
#
#
# 145 is a curious number, as 1! + 4! + 5! = 1 + 24 + 120 = 145.
#
# Find the sum of all numbers which are equal to the sum of the factorial of their digits.
#
# Note: as 1! = 1 and 2! = 2 are not sums they are not included.

# %%
# factorial

def factorial(num):
    total=1
    while num>1:
        total = total * num
        num-=1
    return total

for i in range(1,10):
    total=0
    for j in str(i):
        total += factorial(int(j))
    print(i,total)
# Out:
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
# 6 720
# 7 5040
# 8 40320
# 9 362880

# %%
# digit-factorial-sum, ~200

def factorial(num):
    total=1
    while num>1:
        total = total * num
        num-=1
    return total

for i in range(1,200):
    total=0
    for j in str(i):
        total += factorial(int(j))
    if total == i:
        print("loop:{} factorial_sum:{} True".format(i,total))
    else:
        print("loop:{} factorial_sum:{}".format(i,total))
# Out:
# loop:1 factorial_sum:1 True
# loop:2 factorial_sum:2 True
# loop:3 factorial_sum:6
# loop:4 factorial_sum:24
# loop:5 factorial_sum:120
# loop:6 factorial_sum:720
# loop:7 factorial_sum:5040
# loop:8 factorial_sum:40320
# loop:9 factorial_sum:362880
# loop:10 factorial_sum:2
# loop:11 factorial_sum:2
# loop:12 factorial_sum:3
# loop:13 factorial_sum:7
# loop:14 factorial_sum:25
# loop:15 factorial_sum:121
# loop:16 factorial_sum:721
# loop:17 factorial_sum:5041
# loop:18 factorial_sum:40321
# loop:19 factorial_sum:362881
# loop:20 factorial_sum:3
# loop:21 factorial_sum:3
# loop:22 factorial_sum:4
# loop:23 factorial_sum:8
# loop:24 factorial_sum:26
# loop:25 factorial_sum:122
# loop:26 factorial_sum:722
# loop:27 factorial_sum:5042
# loop:28 factorial_sum:40322
# loop:29 factorial_sum:362882
# loop:30 factorial_sum:7
# loop:31 factorial_sum:7
# loop:32 factorial_sum:8
# loop:33 factorial_sum:12
# loop:34 factorial_sum:30
# loop:35 factorial_sum:126
# loop:36 factorial_sum:726
# ...

# %%
# ~ 10M
import time
start = time.time()

def factorial(num):
    total=1
    while num>1:
        total = total * num
        num-=1
    return total

for i in range(1,10000000):
    total=0
    for j in str(i):
        total += factorial(int(j))
    if total == i:
        print("loop:{} factorial_sum:{} True".format(i,total))

print("Calculation time:",time.time()-start)
# Out:
# loop:1 factorial_sum:1 True
# loop:2 factorial_sum:2 True
# loop:145 factorial_sum:145 True
# loop:40585 factorial_sum:40585 True
# Calculation time: 57.24419379234314

# %%
# prove max range
# possible to 7 digit

def factorial(num):
    total=1
    while num>1:
        total = total * num
        num-=1
    return total

for i in range(1,9):
    print("9"*i, factorial(9)*i)
# Out:
# 9 362880
# 99 725760
# 999 1088640
# 9999 1451520
# 99999 1814400
# 999999 2177280
# 9999999 2540160
# 99999999 2903040

# %%
# factorial

def factorial(num):
    total=1
    while num>1:
        total = total * num
        num-=1
    return total
fact1={}
fact2=[]
for i in range(1,10):
    fact1[i]= factorial(i)
    fact2.append(factorial(i))
print(fact1)
print(fact2)
# Out:
# {1: 1, 2: 2, 3: 6, 4: 24, 5: 120, 6: 720, 7: 5040, 8: 40320, 9: 362880}
# [1, 2, 6, 24, 120, 720, 5040, 40320, 362880]

# %%
fac1={1: 1, 2: 2, 3: 6, 4: 24, 5: 120, 6: 720, 7: 5040, 8: 40320, 9: 362880}
fac2=[1, 2, 6, 24, 120, 720, 5040, 40320, 362880]
a='5'
print(fac1[a])
print(fac2[5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-40bc1807510c> in <module>()
#       2 fac2=[1, 2, 6, 24, 120, 720, 5040, 40320, 362880]
#       3 a='5'
# ----> 4 print(fac1[a])
#       5 print(fac2[5])
#
# KeyError: '5'

# %%
fac2=[1, 2, 6, 24, 120, 720, 5040, 40320, 362880]

def func(num,string,total,count):
    if count==0:
        if len(string)==len(str(total)):
            print(string)
            return
        else :
            return
    for i in fac[]:
        string+str(i)
        total+fac[i]
        func(i,string+str(i),total+fac[i],count-1)

# %%
len(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a95e54e61f62> in <module>()
# ----> 1 len(123)
#
# TypeError: object of type 'int' has no len()
